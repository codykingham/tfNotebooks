# %% [markdown]
# # Categorizing Part of Speech Tags for BDB
#
# The categories are:
# 1. agent
# 2. object
# 3. place
#
# For this task, I used 1) [openscripture's BDB text](https://github.com/openscriptures/HebrewLexicon). For this process, I wrote an interactive script to iterate through all of the pos tags, present me with samples of the lexemes, and add them to a dictionary. Many of the pos tags are simply too vague to mine any category data from (for example: `n.m.pl.`). For pos tags that contained less than 5 lexemes, I frequently looked up the definitions in BDB. Even if the pos tag was vague, if the handful of its members neatly fell into a category, I kept them. The results are written to 2 csv files, one which contains categorised pos tags, and the other which contains the rejected pos tags (for potential processing later on).

# %%
from lxml import etree

tree = etree.parse("../github/textfabric_notebooks/BrownDriverBriggs.xml")
root = tree.getroot()
namespace = {'None':'http://openscriptures.github.com/morphhb/namespace'}

# %%
pos_inventory = set()

for entry in root.findall('None:part/None:section/None:entry/None:pos', namespace):
    pos = entry.text
    if pos.split('.')[0] == 'n':
        pos_inventory.add(pos)
        
for pos in pos_inventory:
    if 'loc' in pos:
        print(pos)
# Out:
# n.pr.loc

# %%
pos_inventory
# Out:
# {'n',
#  'n. [m.]',
#  'n. abstr',
#  'n. f',
#  'n. gent',
#  'n. m',
#  'n.[f.]',
#  'n.[f.]pl',
#  'n.[f.pl.]',
#  'n.[m',
#  'n.[m.,f.]',
#  'n.[m.?]',
#  'n.[m.]',
#  'n.[m.]coll',
#  'n.[m.]du',
#  'n.[m.]intens',
#  'n.[m.]pl',
#  'n.[m.]pl.abstr',
#  'n.[m.]pl.intens',
#  'n.coll',
#  'n.coll.f',
#  'n.f',
#  'n.f.abstr',
#  'n.f.abstr.pl',
#  'n.f.coll',
#  'n.f.cstr',
#  'n.f.denom',
#  'n.f.du',
#  'n.f.emph',
#  'n.f.pl',
#  'n.f.pl.intens',
#  'n.f.pr.putei',
#  'n.f.unit',
#  'n.f.verbal',
#  'n.gent',
#  'n.gent.coll',
#  'n.gent.pl',
#  'n.indecl',
#  'n.m',
#  'n.m.',
#  'n.m.[pl.]',
#  'n.m.coll',
#  'n.m.dei',
#  'n.m.denom',
#  'n.m.du',
#  'n.m.emph',
#  'n.m.epith',
#  'n.m.pers',
#  'n.m.pl',
#  'n.m.pl.abstr',
#  'n.m.pl.emph',
#  'n.pl',
#  'n.pl.[m.]',
#  'n.pl.[m.] abstr',
#  'n.pl.abstr',
#  'n.pl.f.abstr',
#  'n.pl.gent',
#  'n.pl.indecl',
#  'n.pl.m',
#  'n.pr',
#  'n.pr.',
#  'n.pr.[m.]',
#  'n.pr.deae',
#  'n.pr.dei',
#  'n.pr.div',
#  'n.pr.divin',
#  'n.pr.f',
#  'n.pr.fl',
#  'n.pr.flum',
#  'n.pr.font',
#  'n.pr.gent',
#  'n.pr.gent.',
#  'n.pr.gent.coll',
#  'n.pr.gent.pl',
#  'n.pr.loc',
#  'n.pr.m',
#  'n.pr.m.',
#  'n.pr.m.coll',
#  'n.pr.m.pl',
#  'n.pr.mens',
#  'n.pr.mont',
#  'n.pr.mont.',
#  'n.pr.pers',
#  'n.pr.pers.m',
#  'n.pr.pl.gent',
#  'n.pr.pl.gent.',
#  'n.pr.rup',
#  'n.pr.terr',
#  'n.pr.terr.',
#  'n.pr.terr.m',
#  'n.verb'}

# %%
def assign_pos(pos_set):
    pos_to_cat = {}
    no_addition = set()
    
    typ_long = {'ag':'agent','pl':'place','ob':'object'}
    
    for pos in pos_set:
        print(pos)
        
        forms = list()
        
        for entry in root.findall('None:part/None:section/None:entry/None:pos', namespace):
            cur_pos = entry.text
            if cur_pos == pos:
                parent = entry.getparent()
                text = parent.findall('None:w', namespace)[0]
                forms.append(text.text)         
                
        while True:
            cont = input('s/n/a?')
            if cont not in {'s','sa','n','a'}:
                print('typo...')
                continue
            if cont == 's': #sample
                print(forms[:5])
            elif cont == 'sa':
                print(forms)
            elif cont == 'n':  # no addition
                no_addition.add(pos)
                break
            elif cont == 'a': # add
                while True:
                    typ = input('type?')
                    if typ not in {'ag','pl','ob'}:
                        print('typo...')
                        continue
                    typ = typ_long[typ]
                    kind = input('kind?')
                    if kind == 'edit':
                        continue
                    pos_to_cat[pos] = {typ : kind}
                    break
                break
        
    return (pos_to_cat, no_addition)

# %%
pos_assignents = assign_pos(pos_inventory)
# Out:
# n.pl.m
# s/n/a?s
# ['תַּחֲלֻאִים']
# s/n/a?a
# type?ob
# kind?abstract
# n.pr.pers.m
# s/n/a?s
# ['חָם', 'כּוּשׁ']
# s/n/a?a
# type?ag
# kind?person
# n.coll.f
# s/n/a?s
# ['צֹאן']
# s/n/a?a
# type?ag
# kind?animal
# n. m
# s/n/a?s
# ['עָשִׁיר', 'יְתוּר']
# s/n/a?a
# type?ag
# kind?person
# n.pr.mont
# s/n/a?s
# ['הֹר', 'חֹרֵב', 'חֶרְמוֹן', 'יְעָרִים', 'לְבָנוֹן']
# s/n/a?a
# type?pl
# kind?name
# n.m.pl
# s/n/a?s
# ['אֲחַשְׁדַּרְפְּנִים', 'אֱלֹהִים', 'בִּעוּתִים', 'בַּרְקָנִים', 'בַּרְבֻּרִים']
# s/n/a?n
# n.[m.]coll
# s/n/a?s
# ['אָזֵן', 'עֲדִי', 'פּוֹל', 'צֹרְפִי', 'שַׁ֫יִת']
# s/n/a?sa
# ['אָזֵן', 'עֲדִי', 'פּוֹל', 'צֹרְפִי', 'שַׁ֫יִת']
# s/n/a?a
# type?ob
# kind?physical
# n.[m.]pl.intens
# s/n/a?s
# ['שַׁעֲשֻׁעִים', 'רַחֲמִין']
# s/n/a?a
# type?ob
# kind?abstract
# n.pr.gent.coll
# s/n/a?s
# ['עֲרָב']
# s/n/a?a
# type?ag
# kind?person
# n.f.denom
# s/n/a?s
# ['אַרְעִי']
# s/n/a?n
# n.[f.pl.]
# s/n/a?s
# ['רָאמוֹת']
# s/n/a?a
# type?ob
# kind?physical
# n.indecl
# s/n/a?s
# ['שִׁשִּׁים', 'שְׁלֹשִׁים', 'תִּשְׁעִים', 'שִׁתִּין', 'תְּלָתִין']
# s/n/a?sa
# ['שִׁשִּׁים', 'שְׁלֹשִׁים', 'תִּשְׁעִים', 'שִׁתִּין', 'תְּלָתִין']
# s/n/a?n
# n.pr.m.
# s/n/a?s
# ['מעץ']
# s/n/a?a
# type?ag
# kind?person
# n.coll
# s/n/a?s
# ['שִׁמְעִי']
# s/n/a?a
# type?ag
# kind?person
# n.[m
# s/n/a?s
# ['גְּדוּד']
# s/n/a?a
# type?ag
# kind?person
# n.m.coll
# s/n/a?s
# ['פִּרְחָח', 'רָהִיט']
# s/n/a?n
# n.pr.fl
# s/n/a?s
# ['אוּלַי', 'אֲמָנָה', 'אָרְנוֹן', 'יַבֹּק', 'גִּיחוֹן']
# s/n/a?n
# n.pr.terr
# s/n/a?s
# ['אֲרָרַט', 'בִּתְרוֹן', 'מָגוֹג', 'חַדְרָ֔ךְ', 'חֲוִילָה']
# s/n/a?a
# type?pl
# kind?name
# n.f.abstr.pl
# s/n/a?s
# ['בְּחוּרִים']
# s/n/a?n
# n.[f.]
# s/n/a?s
# ['אֹ֫דֶם', 'אֵלוֹן', 'אַצִּיל', 'בֹּ֫הֶן', 'דָּֽרְבֹנָה']
# s/n/a?sa
# ['אֹ֫דֶם', 'אֵלוֹן', 'אַצִּיל', 'בֹּ֫הֶן', 'דָּֽרְבֹנָה', 'זוּלָה', 'זָרָא', 'זְכוּכִית', 'מִזְלָגָה', 'זְמוֹרָה', 'חָגָּא', 'חָזוֹת', 'חָלָץ', 'חַרְצֻבָּה', 'מְכֵרָה', 'כֵּילַפּוֹת', 'מִכְלָה', 'כֶּ֫רַע', 'מְלִיצָה', 'נַ֫חַת', 'נְחֹ֫שֶׁת', 'נְטִיפָה', 'נְכֹת', 'סַלְסִלָּה', 'עֲרָבָה', 'מִפְעָלָה', 'פֹּת', 'פְּתִיחָה', 'צַחְצָחָה', 'צֵלָחָה', 'קָאַת', 'קְפָדָה', 'מַקְצֻעָה', 'קַרְסֹל', 'קֶ֫סֶת', 'רַ֫חַת', 'רִיפָה', 'רַמָּךְ', 'רְעָלָה', 'רַפְסֹדָה', 'רְתֻקָה', 'מַשְׂרֵפָה', 'שְׁבוֹ', 'שֶׁ֫גֶר', 'שׁוֹק', 'שְׁרִיקָה', 'שֵׁרָה', 'אֲרַע', 'אֲרַק', 'אֶשָּׁא', 'בְּרַךְ', 'דְּרַע', 'אֶדְרַע', 'כִּכֵּר', 'נֹ֫גַהּ', 'עֵז', 'רְגַל', 'שַׂבְּכָא', 'שֵׁן']
# s/n/a?a
# type?ob
# kind?half
# n.m.pers
# s/n/a?s
# ['שַׁעַשְׁגַּז']
# s/n/a?a
# type?ag
# kind?person
# n.[m.]intens
# s/n/a?s
# ['עַבְטִיט']
# s/n/a?n
# n.f.cstr
# s/n/a?s
# ['אַחֲרִית']
# s/n/a?a
# type?ob
# kind?abstract
# n.f.verbal
# s/n/a?s
# ['אֲסֵפָה', 'בַּקָּרָה']
# s/n/a?a
# type?ob
# kind?abstract
# n.m.emph
# s/n/a?s
# ['מֹאזֵנְיָא']
# s/n/a?n
# n.m.
# s/n/a?s
# ['מוֹץ']
# s/n/a?sa
# ['מוֹץ']
# s/n/a?n
# n.[m.]pl
# s/n/a?s
# ['אֻרִים', 'אֲלְגּוּמִים', 'אַלְמֻגִּים', 'בְּאֻשִׁים', 'אֲבַטִּחִים']
# s/n/a?n
# n.pr.font
# s/n/a?s
# ['עֵ֫שֶׂק', 'שִׁלֹחַ']
# s/n/a?a
# type?pl
# kind?name
# n.pr.pl.gent.
# s/n/a?s
# ['אֲפָֽרְסַתְּכָיֵא']
# s/n/a?a
# type?ag
# kind?person
# n.f.unit
# s/n/a?s
# ['נְמָלָה']
# s/n/a?a
# type?ob
# kind?measurement
# n.pr.gent.pl
# s/n/a?s
# ['אַשּׁוּרִם', 'רוֹדָנִים', 'שׁוּשַׁנְכָיֵא']
# s/n/a?a
# type?ag
# kind?person
# n.gent.coll
# s/n/a?s
# ['קֵינִי']
# s/n/a?a
# type?ag
# kind?person
# n.m.denom
# s/n/a?s
# ['בּוֹקֵר']
# s/n/a?a
# type?ag
# kind?person
# n.m.du
# s/n/a?s
# ['מַתְנַ֫יִם']
# s/n/a?a
# type?ob
# kind?physical
# n.pr.loc
# s/n/a?s
# ['אֶ֫בֶץ', 'אֶגְלַ֫יִם', 'אַדְמָה', 'אֲדָמִי הַנֶּ֫קֶב', 'אַדָּן']
# s/n/a?a
# type?pl
# kind?kind/name
# n.pr.
# s/n/a?s
# ['סִיוָן']
# s/n/a?a
# type?ob
# kind?abstract
# n.f
# s/n/a?s
# ['אֲבֵדָה', 'אֲבַדּוֹן', 'אֲבִיּוֹנָה', 'אִבְחָה', 'אָבֵל']
# s/n/a?n
# n.pr.f
# s/n/a?s
# ['אֲבִיגַ֫יִל', 'אֲבִיטָ֑ל', 'אֲבִישַׁג', 'אָהֳלָה', 'אָהֳלִיבָה']
# s/n/a?a
# type?ag
# kind?person
# n.pr
# s/n/a?s
# ['אֲבַדּוֹן', 'אָהֳלִיבָמָה', 'אוֹפִיר', 'אַחְלָ֑י', 'אַלְמוֹדָד']
# s/n/a?a
# type?ag
# kind?person
# n.f.pl
# s/n/a?s
# ['אֲבַעְבֻּעֹת', 'בַּטֻּחוֹת', 'מְבַשְּׁלוֹת', 'מִגְבָּלֹת', 'מִגְבָּעוֹת']
# s/n/a?n
# n.pr.pl.gent
# s/n/a?s
# ['אֲפָֽרְסָיֵא']
# s/n/a?a
# type?ag
# kind?person
# n.[m.,f.]
# s/n/a?s
# ['לְבִי']
# s/n/a?n
# n.pl.abstr
# s/n/a?s
# ['כִּפֻּרִים', 'עִוְעִים', 'עָלוּמִים', 'עָשׁוּקִים', 'שִׁכֻּלִים']
# s/n/a?a
# type?ob
# kind?abstract
# n.f.pl.intens
# s/n/a?s
# ['עֹלֵלוֹת']
# s/n/a?n
# n.m.pl.emph
# s/n/a?s
# ['גְּדָֽבְרַיָּא']
# s/n/a?n
# n.gent.pl
# s/n/a?s
# ['לוּב', 'עֵלְמָיֵא']
# s/n/a?a
# type?ag
# kind?person
# n.f.du
# s/n/a?s
# ['מְצִלְתַּיִם', 'שִׁבְעָתַיִם']
# s/n/a?n
# n.pr.m.pl
# s/n/a?s
# ['אֵימִים', 'סֻכִּיִּים', 'תִּרְעָתִים']
# s/n/a?a
# type?ag
# kind?person
# n.pr.mont.
# s/n/a?s
# ['כַּרְמֶל', 'סִינַי']
# s/n/a?a
# type?pl
# kind?name
# n.pr.terr.
# s/n/a?s
# ['עֵ֫דֶן']
# s/n/a?a
# type?pl
# kind?name
# n.pr.gent
# s/n/a?s
# ['אַשּׁוּר', 'גּוֹיִם', 'גַּמָּדִים', 'זוּזִים', 'זַמְזֻמִּים']
# s/n/a?a
# type?ag
# kind?person
# n. abstr
# s/n/a?s
# ['גְּאוּלַי']
# s/n/a?a
# type?ob
# kind?abstract
# n.pr.div
# s/n/a?s
# ['כְּמוֹשׁ', 'מֹ֫לֶךְ', 'מִלכֹּם', 'מְנִי', 'מְרֹדָךְ']
# s/n/a?a
# type?ag
# kind?person
# n.pr.terr.m
# s/n/a?s
# ['בָּשָׁן']
# s/n/a?a
# type?pl
# kind?name
# n.[m.?]
# s/n/a?s
# ['קֹ֫שֶׁט']
# s/n/a?a
# type?ob
# kind?physical
# n.f.emph
# s/n/a?s
# ['נֶבְרַשְׁתָּא']
# s/n/a?n
# n.pr.m
# s/n/a?s
# ['אֲבַגְתָא', 'אֲבִי־עַלְבוֹן', 'אֲבִיאֵל', 'אֲבִיאָסָף', 'אֲבִידָן']
# s/n/a?a
# type?ag
# kind?half
# n.pl.[m.] abstr
# s/n/a?s
# ['פְּקוּדִים']
# s/n/a?a
# type?ob
# kind?abstract
# n. [m.]
# s/n/a?s
# ['לָבִיא', 'מֵן', 'נָכוֹן', 'סֹכֵךְ', 'עֵירֹם']
# s/n/a?n
# n.pr.m.coll
# s/n/a?s
# ['אֱמֹרִי']
# s/n/a?a
# type?ag
# kind?person
# n.[m.]
# s/n/a?s
# ['אֵב', 'אֹבֵד', 'אַבְדָ֑ן', 'אֵ֫בֶה', 'אֹבֶן']
# s/n/a?n
# n.[m.]du
# s/n/a?s
# ['מאזן', 'כִּלְאַיִם', 'מֶלְקָחַ֫יִם', 'מִשְׁפְּתַ֫יִם', 'שְׁפַתַּ֫יִם']
# s/n/a?sa
# ['מאזן', 'כִּלְאַיִם', 'מֶלְקָחַ֫יִם', 'מִשְׁפְּתַ֫יִם', 'שְׁפַתַּ֫יִם']
# s/n/a?a
# type?ob
# kind?physical
# n.verb
# s/n/a?s
# ['חֹתֵן', 'רֵעַ']
# s/n/a?a
# type?ag
# kind?person
# n.pr.rup
# s/n/a?s
# ['סֶ֑נֶּה']
# s/n/a?a
# type?pl
# kind?name
# n.m.epith
# s/n/a?s
# ['יָרֵב']
# s/n/a?n
# n.pr.dei
# s/n/a?s
# ['יהוה', 'יָהּ', 'כִּיּוּן', 'רִמּוֹן']
# s/n/a?a
# type?ag
# kind?god
# n.m.pl.abstr
# s/n/a?s
# ['תַּעֲלוּלִים']
# s/n/a?a
# type?ob
# kind?abstract
# n.gent
# s/n/a?s
# ['חִתִּי', 'כִּתִּי', 'עִבְרִי', 'יְהוּדַי', 'לֵוָי']
# s/n/a?a
# type?ag
# kind?person
# n
# s/n/a?s
# ['כְּנָת', 'כַּפֹּרֶת', 'מִסַּת', 'עָבוּר', 'עָלֵז']
# s/n/a?n
# n.f.abstr
# s/n/a?a
# type?ob
# kind?abstract
# n.m
# s/n/a?s
# ['אָבִיב', 'אָב', 'אֵ֫בֶל', 'אֵבוּס', 'אָבָק']
# s/n/a?n
# n.pr.pers
# s/n/a?s
# ['מְהֵיטַבְאֵל', 'יָפִיעַ']
# s/n/a?a
# type?ag
# kind?person
# n.f.pr.putei
# s/n/a?s
# ['שִׁבְעָה']
# s/n/a?n
# n. f
# s/n/a?s
# ['אֶ֫רֶץ', 'שׂוּמָה']
# s/n/a?n
# n.pl.indecl
# s/n/a?s
# ['שְׁמֹנִים', 'עֶשְׂרִין']
# s/n/a?n
# n. gent
# s/n/a?s
# ['עֲרָבִי']
# s/n/a?a
# type?ag
# kind?person
# n.pr.divin
# s/n/a?s
# ['הֲדַדְרִמּוֹן', 'הֲדַדְרִמּוֹן']
# s/n/a?n
# n.[m.]pl.abstr
# s/n/a?s
# ['חֲנֻטִים', 'טִפֻּחִים', 'פָּדוּיִם', 'תֵּעְתֻּעִים']
# s/n/a?a
# type?ob
# kind?abstract
# n.pr.gent.
# s/n/a?s
# ['לְהָבִים']
# s/n/a?n
# n.pr.flum
# s/n/a?s
# ['פַּרְפַּר', 'פְּרָת', 'שִׁיחוֹר', 'שִׁיחוֹר לִבְנַת']
# s/n/a?sa
# ['פַּרְפַּר', 'פְּרָת', 'שִׁיחוֹר', 'שִׁיחוֹר לִבְנַת']
# s/n/a?a
# type?pl
# kind?name
# n.pl.f.abstr
# s/n/a?s
# ['חֲלַקְלַקּוֹת']
# s/n/a?a
# type?ob
# kind?abstract
# n.pr.mens
# s/n/a?s
# ['שְׁבָט']
# s/n/a?n
# n.pr.deae
# s/n/a?s
# ['עַשְׁתֹּ֫רֶת']
# s/n/a?a
# type?ag
# kind?god
# n.[f.]pl
# s/n/a?s
# ['מַזָּלוֹת', 'מַזָּרוֹת', 'נְעוּרוֹת', 'פְּנִינִים', 'פַּקֻּעֹת']
# s/n/a?n
# n.f.coll
# s/n/a?s
# ['אַרְזָה', 'חרסות', 'עֵצָה', 'פארה', 'צִרְעָה']
# s/n/a?n
# n.pr.[m.]
# s/n/a?s
# ['אֲדָר', 'אֵ֫צֶל', 'אֲשִׁימָא', 'יְהַלֶּלְאֵל', 'כִּסְלֵו']
# s/n/a?sa
# ['אֲדָר', 'אֵ֫צֶל', 'אֲשִׁימָא', 'יְהַלֶּלְאֵל', 'כִּסְלֵו']
# s/n/a?n
# n.pl
# s/n/a?s
# ['חֲמִשִּׁים', 'לְבִבָה', 'שִׁבְעִים']
# s/n/a?n
# n.m.[pl.]
# s/n/a?s
# ['שֶׁנְהַבִּים']
# s/n/a?n
# n.pl.[m.]
# s/n/a?s
# ['זְקֻנִים']
# s/n/a?n
# n.pl.gent
# s/n/a?s
# ['סְבָאִים']
# s/n/a?a
# type?ag
# kind?person
# n.m.dei
# s/n/a?s
# ['שַׁדַּי']
# s/n/a?a
# type?ag
# kind?god

# %%
import csv

fieldnames = ['pos','type','of kind']

pos_data = list( {'pos': pos, 
                  'type': [x for x in typ.keys()][0], 
                  'of kind': [x for x in typ.values()][0]} \ # messy! It's late!
                for pos, typ in pos_assignents[0].items())

with open('BDB_pos_tags.csv','w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(pos_data)

# %%
# these tags are rejected because there is not enough information to assign a category to them

with open('BDB_rejected_posTags.csv','w') as file:
    writer = csv.writer(file)
    writer.writerows(list([pos] for pos in pos_assignents[1]))
