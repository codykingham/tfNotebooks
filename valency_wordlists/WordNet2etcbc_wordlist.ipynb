# %%
from datetime import datetime
last_modified = datetime.now()
print('Notebook last modified on {}'.format(last_modified.__str__()))
# Out:
# Notebook last modified on 2017-01-15 21:52:27.788876

# %% [markdown]
# # WordNet to ETCBC
#
# This is an attempt to map categories to substantive lex objects in ETCBC for valency research. Senses in Princeton Wordnet contain hypernym and hyponym relations, allowing for grouping senses into general categories. The ETCBC contains a gloss feature for every Hebrew term in the database. In order to accomplish some mappings, we need to follow several steps.
#
# 1. retrieve all noun, lexeme objects in etcbc with a mapping to 10 (max) random sample passages
# 2. pass each etcbc gloss from the lexeme to Morphy to get the lexical form in English.
#     * remap the cleaned etcbc gloss to the 10 sample passages
# 3. extract the sample passages from English translations with [XML Bible API](https://www.4-14.org.uk/xml-bible-web-service-api)
#     * tokenize and parse each word in the sample passages
#     * filter out any sample passages that do not contain the lexeme
#     * map each lexeme to its verified sample passage
# 4. feed lexeme and sample passsages to the [Word Sense Disambiguation algorithm](http://www.nltk.org/howto/wsd.html)
#     * map lexeme to wordnet sense
# 5. test the hypernyms for each sense to create the categories
# 6. export the new list
#
# Along the way, keep track of how many lexemes we account for from ETCBC so that we can weed out solvable problems in the mapping process.
#
# ## Updates:
#
# √ 15.01.17, removed some spurious lexemes. See [Special Adjustments](#Special-Adjustments:)

# %%
from collections import *
from tf.fabric import Fabric

TF = Fabric(modules='hebrew/etcbc4c')
api = TF.load('book chapter verse gloss lex g_word_utf8 sp')
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 2.3.0
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
# Data docs     : https://etcbc.github.io/text-fabric-data
# Shebanq docs  : https://shebanq.ancient-data.org/text
# Slack team    : https://shebanq.slack.com/signup
# Questions? Ask shebanq@ancient-data.org for an invite to Slack
# 109 features found and 0 ignored
#   0.00s loading features ...
#    |     0.01s B book                 from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B chapter              from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B verse                from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.20s B g_word_utf8          from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B gloss                from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.15s B lex                  from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.28s B sp                   from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.00s Feature overview: 103 nodes; 5 edges; 1 configs; 7 computeds
#   5.72s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # 1. retrieve noun, lexeme objects in etcbc with a mapping to 10 (max) random sample passages

# %%
etcbcLex = defaultdict(set) # mapping from etcbc word nodes to 10 max sample passages

indent(reset = True)
info('beginning search...')
for lex in F.otype.s('lex'):
    if F.sp.v(lex) != 'subs': continue
    samples = set(L.d(lex, otype = 'word')) # randomize with set
    samples = list(samples)[:10] if len(samples) > 10 else samples # pull only 10
    samples = set(T.sectionFromNode(n) for n in samples) # pull passage info
    etcbcLex[lex] = set(samples)
    if len(etcbcLex) % 500 == 0: info('{} words processed...'.format(len(etcbcLex)))
        
avgSampleLen = round(sum( len(passages) for word in etcbcLex for passages in etcbcLex[word] ) / len(etcbcLex),2)
        
info('Complete with {} words and average {} sample passages'.format(len(etcbcLex),avgSampleLen))
# Out:
#   0.00s beginning search...
#   0.21s 500 words processed...
#   0.35s 1000 words processed...
#   0.47s 1500 words processed...
#   0.57s 2000 words processed...
#   0.64s 2500 words processed...
#   0.70s 3000 words processed...
#   0.74s 3500 words processed...
#   0.84s 4000 words processed...
#   0.86s Complete with 4077 words and average 13.35 sample passages

# %%
list(etcbcLex.items())[:2]
# Out:
# [(1436896,
#   {('Deuteronomy', 11, 12),
#    ('Ezekiel', 44, 30),
#    ('Genesis', 1, 1),
#    ('Jeremiah', 2, 3),
#    ('Jeremiah', 49, 34),
#    ('Jeremiah', 49, 35),
#    ('Nehemiah', 12, 44),
#    ('Numbers', 15, 20),
#    ('Numbers', 15, 21),
#    ('Proverbs', 3, 9)}),
#  (1436898,
#   {('1_Chronicles', 19, 13),
#    ('2_Kings', 4, 7),
#    ('Ezekiel', 28, 13),
#    ('Genesis', 1, 1),
#    ('Genesis', 1, 2),
#    ('Genesis', 43, 23),
#    ('Joshua', 18, 3),
#    ('Psalms', 7, 4),
#    ('Psalms', 55, 15)})]

# %%
# a set to track which lexemes are weeded out
lexTracker = set(etcbcLex.keys())
len(lexTracker)
# Out:
# 4077

# %% [markdown]
# # 2. pass each etcbc gloss from the lexeme to Morphy to get the lexical form in English

# %%
from nltk.corpus import wordnet as wn

# %%
cleanGlosses = {}
changes = set()

for lexNode, samples in etcbcLex.items():
    lex = F.gloss.v(lexNode)
    morph = wn.morphy(lex, wn.NOUN)
    if morph:
        cleanGlosses[lexNode] = {'WNgloss':morph, 'samples': samples}
        if morph != lex:
            changes.add('{} --> {}'.format(lex, morph))
        
print('glosses found: {}'.format(len(cleanGlosses)))
print('etcbc words lost: {}'.format(len(lexTracker)-len(cleanGlosses)))
print('total changes: {}'.format(len(changes)))
print('sample changes: {}'.format('\n\t\t'.join(list(changes)[:10])))
# Out:
# glosses found: 3172
# etcbc words lost: 905
# total changes: 84
# sample changes: members --> member
# 		giants --> giant
# 		adders --> adder
# 		loops --> loop
# 		generations --> generation
# 		robes --> robe
# 		coverlets --> coverlet
# 		handshakes --> handshake
# 		charmers --> charmer
# 		hostages --> hostage

# %%
etcbcLex = cleanGlosses
lexTracker = set(etcbcLex.keys()) & lexTracker
print('remaining words:', len(lexTracker))
# Out:
# remaining words: 3172

# %% [markdown]
# # 3. extract the sample passages from English translations with XML Bible API

# %%
import requests
import time
from lxml import etree
from spacy.en import English

verseCache = defaultdict(dict)

# %%
# first retrieve all verses 

passageText = {}
passagesToGet = set(sect for data in etcbcLex for sect in etcbcLex[data]['samples'])
translationPreferences = ('nasb','ylt','akjv','web','kjv') # see https://www.4-14.org.uk/xml-bible-web-service-api
apiURL = 'http://api.preachingcentral.com/bible.php?passage={passage}&version={version}'

def fix_book(bookString):
    if '_' in bookString:
        return ' '.join(bookString.split('_'))
    else:
        return bookString

def getRequest(passages, version):
    passages = set('{} {}:{}'.format(fix_book(passa[0]), passa[1], passa[2]) for passa in passages)
    passages = ', '.join(passages)
    requestURL = apiURL.format(passage=passages, version=version)
    rawData = requests.get(requestURL).content
    bibleRoot = etree.fromstring(rawData)
    for result in bibleRoot.findall('range/result'):
        passage = result.text
        try:
            text = result.findall('../item/text')[0].text
        except IndexError:
            info('not found: {}'.format(result.text))
        verseCache[version].update({passage: text})

def getPassages(passageSet, version):
    assembledRequest = set()
    for count, passage in enumerate(passageSet):
        if passage in verseCache[version]:
            continue
        assembledRequest.add(passage)
        if any([count != 0 and count % 400 == 0, # create requests of max 400 verses at a time 
                count == len(passageSet)-1  
               ]):
            getRequest(assembledRequest, version) # stores the verse in the cache every 400 verses
            time.sleep(3)
            assembledRequest = set()
            info('verses logged at count: {}'.format(count))
            info('total verses: {}'.format(len(verseCache[version])))
            
for translation in translationPreferences:
    break # the results of this query have been pushed to a json file (cf. below)
    indent(reset=True)
    info('preparing {}'.format(translation))
    getPassages(passagesToGet, translation)

# %%
import json 

with open('lexTranslations.json', 'r') as file:
    samples = json.load(file)
    
print(len(samples['nasb']))
# Out:
# 8876

# %% [markdown]
# ## tokenize and parse each word in the sample passages

# %%
parser = English()

# %% [markdown]
# **First a test/demonstration of Spacy. We link אֶרֶץ (earth) with the parsed Spacy text from the NASB. The output results in True**

# %%
test = samples['nasb']['Genesis 1:1']
parsedTest = parser(test)
erets = list(lex for lex in F.otype.s('lex') if F.lex.v(lex) == '>RY/')[0]
testSentence = list(parsedTest.sents)

print(testSentence)
print('lemmatized:\n', list(token.lemma_ for token in testSentence[0]))
print('partOfSpeech:\n', list(token.pos_ for token in testSentence[0]))

# true or false? Now we demonstrate the link from ETCBC to the translation: 
(F.gloss.v(erets),'NOUN') in set((token.lemma_, token.pos_) for token in testSentence[0])
# Out:
# [In the beginning God created the heavens and the earth.]
# lemmatized:
#  ['in', 'the', 'begin', 'god', 'create', 'the', 'heaven', 'and', 'the', 'earth', '.']
# partOfSpeech:
#  ['ADP', 'DET', 'VERB', 'PROPN', 'VERB', 'DET', 'NOUN', 'CONJ', 'DET', 'NOUN', 'PUNCT']
# True

# %% [markdown]
# **tokenize the verses and keep a part of speech**

# %%
lemmatizedSamps = defaultdict(dict)
passageCount = 0

indent(reset = True)
for version, passages in samples.items():
    info('starting {}'.format(version))
    for passage, text in passages.items():
        passageCount += 1
        pText = list(parser(text))
        lemmatizedSamps[version][passage]= {'tokens' : tuple(w.orth_ for w in pText), # for sense disambiguation
                                            'posLem' : set((w.lemma_,w.pos_) for w in pText) # to check for lemma
                                            }
        if passageCount != 0 and passageCount % 1000 == 0:
            info('{} passages processed...'.format(passageCount))
info('\nCOMPLETE! {} passages processed'.format(passageCount))
# Out:
#   0.00s starting nasb
#   3.56s 1000 passages processed...
#   6.27s 2000 passages processed...
#   9.62s 3000 passages processed...
#     12s 4000 passages processed...
#     16s 5000 passages processed...
#     19s 6000 passages processed...
#     21s 7000 passages processed...
#     24s 8000 passages processed...
#     27s starting ylt
#     27s 9000 passages processed...
#     30s 10000 passages processed...
#     32s 11000 passages processed...
#     35s 12000 passages processed...
#     38s 13000 passages processed...
#     41s 14000 passages processed...
#     43s 15000 passages processed...
#     45s 16000 passages processed...
#     48s 17000 passages processed...
#     50s starting akjv
#     51s 18000 passages processed...
#     54s 19000 passages processed...
#     56s 20000 passages processed...
#     59s 21000 passages processed...
#  1m 01s 22000 passages processed...
#  1m 03s 23000 passages processed...
#  1m 06s 24000 passages processed...
#  1m 09s 25000 passages processed...
#  1m 12s 26000 passages processed...
#  1m 13s starting web
#  1m 14s 27000 passages processed...
#  1m 16s 28000 passages processed...
#  1m 19s 29000 passages processed...
#  1m 21s 30000 passages processed...
#  1m 23s 31000 passages processed...
#  1m 26s 32000 passages processed...
#  1m 28s 33000 passages processed...
#  1m 30s 34000 passages processed...
#  1m 33s 35000 passages processed...
#  1m 35s starting kjv
#  1m 36s 36000 passages processed...
#  1m 38s 37000 passages processed...
#  1m 41s 38000 passages processed...
#  1m 43s 39000 passages processed...
#  1m 45s 40000 passages processed...
#  1m 48s 41000 passages processed...
#  1m 50s 42000 passages processed...
#  1m 52s 43000 passages processed...
#  1m 55s 44000 passages processed...
#  1m 56s
# COMPLETE! 44376 passages processed

# %%
from pprint import pprint

pprint(lemmatizedSamps['nasb']['Genesis 1:1'])
# Out:
# {'posLem': {('.', 'PUNCT'),
#             ('and', 'CONJ'),
#             ('begin', 'VERB'),
#             ('create', 'VERB'),
#             ('earth', 'NOUN'),
#             ('god', 'PROPN'),
#             ('heaven', 'NOUN'),
#             ('in', 'ADP'),
#             ('the', 'DET')},
#  'tokens': ('In',
#             'the',
#             'beginning',
#             'God',
#             'created',
#             'the',
#             'heavens',
#             'and',
#             'the',
#             'earth',
#             '.')}

# %% [markdown]
# ### filter out any sample passages that do not contain the lexeme; map each lexeme to its verified sample passage

# %%
# if the sample passage does not contain the exact lexeme,
# move on to the next preferred translation in the preferredTranslations list 

pprint(list(etcbcLex.items())[:2])
# Out:
# [(1436896,
#   {'WNgloss': 'beginning',
#    'samples': {('Deuteronomy', 11, 12),
#                ('Ezekiel', 44, 30),
#                ('Genesis', 1, 1),
#                ('Jeremiah', 2, 3),
#                ('Jeremiah', 49, 34),
#                ('Jeremiah', 49, 35),
#                ('Nehemiah', 12, 44),
#                ('Numbers', 15, 20),
#                ('Numbers', 15, 21),
#                ('Proverbs', 3, 9)}}),
#  (1436901,
#   {'WNgloss': 'heavens',
#    'samples': {('2_Chronicles', 33, 3),
#                ('Deuteronomy', 2, 25),
#                ('Deuteronomy', 28, 24),
#                ('Deuteronomy', 30, 19),
#                ('Deuteronomy', 33, 28),
#                ('Genesis', 1, 1),
#                ('Genesis', 27, 39),
#                ('Isaiah', 49, 13),
#                ('Psalms', 33, 6),
#                ('Zephaniah', 1, 3)}})]

# %%
translationPreferences = ('nasb','akjv','web','kjv') # see https://www.4-14.org.uk/xml-bible-web-service-api

def formatSection(sectionTuple):
    book = fix_book(sectionTuple[0])
    chapter = sectionTuple[1]
    verse = sectionTuple[2]
    return '{} {}:{}'.format(book, chapter, verse)

def getPreferred(lexNode, sectionSet):
    preferredSamples = list()
    lexGloss = etcbcLex[lexNode]['WNgloss']
    for sect in sectionSet:
        sect = formatSection(sect)
        for prefTrans in translationPreferences:
            try:
                if (lexGloss, 'NOUN') in lemmatizedSamps[prefTrans][sect]['posLem']:
                    tokens = lemmatizedSamps[prefTrans][sect]['tokens']
                    preferredSamples.append({'translation':prefTrans, 'reference' : sect, 'tokens' : tokens})
                    break
            except KeyError:
                continue
    return preferredSamples

# create the new mapping:

lexToGoodSamples = defaultdict(dict)
noSamplesRemaining = set()

indent(reset=True)
info('processing samples...')
for lex, lexDat in etcbcLex.items():
    samples = lexDat['samples']
    processedSamples = getPreferred(lex, samples)
    if not processedSamples:
        noSamplesRemaining.add(lex)
        continue
    lexToGoodSamples[lex] = {'WNgloss': lexDat['WNgloss'], 
                             'samples' : processedSamples}
    
avgSampleLen = round(sum( len(passages) for word in lexToGoodSamples \
                         for passages in lexToGoodSamples[word] ) / len(lexToGoodSamples),2)

info('COMPLETE! Average remaining samples per lex: {}'.format(avgSampleLen))
info('Culled lex objects: {}'.format(len(noSamplesRemaining)))
info('Remaining lex objects: {}'.format(len(lexToGoodSamples)))
# Out:
#   0.00s processing samples...
#   0.08s COMPLETE! Average remaining samples per lex: 14.0
#   0.08s Culled lex objects: 1127
#   0.08s Remaining lex objects: 2045

# %%
# sample 
etcbcLex = lexToGoodSamples
pprint(list(etcbcLex.items())[:1])
# Out:
# [(1436896,
#   {'WNgloss': 'beginning',
#    'samples': [{'reference': 'Deuteronomy 11:12',
#                 'tokens': ('a',
#                            'land',
#                            'for',
#                            'which',
#                            'the',
#                            'LORD',
#                            'your',
#                            'God',
#                            'cares',
#                            ';',
#                            'the',
#                            'eyes',
#                            'of',
#                            'the',
#                            'LORD',
#                            'your',
#                            'God',
#                            'are',
#                            'always',
#                            'on',
#                            'it',
#                            ',',
#                            'from',
#                            'the',
#                            'beginning',
#                            'even',
#                            'to',
#                            'the',
#                            'end',
#                            'of',
#                            'the',
#                            'year',
#                            '.'),
#                 'translation': 'nasb'},
#                {'reference': 'Jeremiah 49:34',
#                 'tokens': ('That',
#                            'which',
#                            'came',
#                            'as',
#                            'the',
#                            'word',
#                            'of',
#                            'the',
#                            'LORD',
#                            'to',
#                            'Jeremiah',
#                            'the',
#                            'prophet',
#                            'concerning',
#                            'Elam',
#                            ',',
#                            'at',
#                            'the',
#                            'beginning',
#                            'of',
#                            'the',
#                            'reign',
#                            'of',
#                            'Zedekiah',
#                            'king',
#                            'of',
#                            'Judah',
#                            ',',
#                            'saying',
#                            ':'),
#                 'translation': 'nasb'}]})]

# %% [markdown]
# ## 4. feed lexeme and sample passsages to the [Word Sense Disambiguation algorithm](http://www.nltk.org/howto/wsd.html)
# ### map lexeme to wordnet sense

# %%
from nltk.wsd import lesk # disambiguation algorithm

threshold = 2

def disambiguate(gloss, samples):
    scores = Counter()
    for sample in samples:
        proposedSynset = lesk(sample, gloss, 'n')
        if proposedSynset:
            scores[proposedSynset] += 1
    if not scores or sum(scores.values()) < threshold: return None
    return max(scores) # return the simple majority

def pullSamples(lexNode):
    samples = tuple(text['tokens'] for text in etcbcLex[lexNode]['samples'])
    return samples

# create the mapping

mappedToSynset = defaultdict(dict)
culledLexs = set()

indent(reset=True)
info('looking for synsets...')

count = 0

for lexNode, lexDat in list(etcbcLex.items()):
    count += 1    
    samples = pullSamples(lexNode)
    synset = disambiguate(lexDat['WNgloss'], samples)
    if not synset:
        culledLexs.add(lexNode)
        continue
    mappedToSynset[lexNode] = lexDat
    mappedToSynset[lexNode].update({'synset': synset})

info('Culled lex objects: {}'.format(len(culledLexs)))
info('Remaining lex objects: {}'.format(len(mappedToSynset)))
# Out:
#   0.00s looking for synsets...
#   1.49s Culled lex objects: 739
#   1.49s Remaining lex objects: 1306

# %%
hyper = lambda s: s.hypernyms()

for lex, lexDat in list(mappedToSynset.items())[:150]:
    print('{} --> {}\n{}\nHYPERS: {}\n'.format(lexDat['WNgloss'], 
                                               lexDat['synset'].name(), 
                                               lexDat['synset'].definition(),
                                               list(x for x in lexDat['synset'].closure(hyper))
                                  )
         )
# Out:
# beginning --> beginning.n.02
# the time at which something is supposed to begin
# HYPERS: [Synset('point.n.06'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# earth --> worldly_concern.n.01
# the concerns of this life as distinguished from heaven and the afterlife
# HYPERS: [Synset('concern.n.01'), Synset('interest.n.01'), Synset('curiosity.n.01'), Synset('cognitive_state.n.01'), Synset('psychological_state.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# darkness --> iniquity.n.01
# absence of moral or spiritual values
# HYPERS: [Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# face --> face.n.07
# the part of an animal corresponding to the human face
# HYPERS: [Synset('external_body_part.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# water --> water_system.n.02
# a facility that provides a source of water
# HYPERS: [Synset('facility.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# light --> sparkle.n.01
# merriment expressed by a brightness or gleam or animation of countenance
# HYPERS: [Synset('expression.n.01'), Synset('vitality.n.01'), Synset('countenance.n.01'), Synset('energy.n.04'), Synset('appearance.n.01'), Synset('liveliness.n.02'), Synset('quality.n.01'), Synset('animation.n.03'), Synset('attribute.n.02'), Synset('activeness.n.02'), Synset('abstraction.n.06'), Synset('trait.n.01'), Synset('entity.n.01')]
#
# day --> sidereal_day.n.01
# the time for one complete rotation of the earth relative to a particular star, about 4 minutes shorter than a mean solar day
# HYPERS: [Synset('sidereal_time.n.01'), Synset('time_unit.n.01'), Synset('cosmic_time.n.01'), Synset('measure.n.02'), Synset('time.n.05'), Synset('abstraction.n.06'), Synset('attribute.n.02'), Synset('entity.n.01')]
#
# night --> night.n.07
# the time between sunset and midnight
# HYPERS: [Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# evening --> evening.n.03
# the early part of night (from dinner until bedtime) spent in a special way
# HYPERS: [Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# morning --> morning.n.01
# the time period between dawn and noon
# HYPERS: [Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# one --> one.n.02
# a single person or thing
# HYPERS: [Synset('unit.n.04'), Synset('whole.n.01'), Synset('concept.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# firmament --> celestial_sphere.n.01
# the apparent surface of the imaginary sphere on which celestial bodies appear to be projected
# HYPERS: [Synset('surface.n.02'), Synset('boundary.n.01'), Synset('extremity.n.04'), Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# midst --> midst.n.01
# the location of something surrounded by other things
# HYPERS: [Synset('inside.n.01'), Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# place --> topographic_point.n.01
# a point located with respect to surface features of some region
# HYPERS: [Synset('point.n.02'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# sea --> sea.n.03
# turbulent water with swells of considerable size
# HYPERS: [Synset('turbulent_flow.n.01'), Synset('flow.n.04'), Synset('natural_process.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# herb --> herb.n.02
# aromatic potherb used in cookery for its savory qualities
# HYPERS: [Synset('flavorer.n.01'), Synset('ingredient.n.03'), Synset('foodstuff.n.02'), Synset('food.n.01'), Synset('substance.n.07'), Synset('matter.n.03'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# seed --> source.n.03
# anything that provides inspiration for later work
# HYPERS: [Synset('inspiration.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# tree --> tree.n.03
# English actor and theatrical producer noted for his lavish productions of Shakespeare (1853-1917)
# HYPERS: []
#
# fruit --> yield.n.03
# an amount of a product
# HYPERS: [Synset('product.n.02'), Synset('creation.n.02'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# kind --> kind.n.01
# a category of things distinguished by some common characteristic or quality
# HYPERS: [Synset('category.n.02'), Synset('concept.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# lamp --> lamp.n.02
# a piece of furniture holding one or more electric light bulbs
# HYPERS: [Synset('furniture.n.01'), Synset('furnishing.n.02'), Synset('instrumentality.n.03'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# sign --> signboard.n.01
# structure displaying a board on which advertisements can be posted
# HYPERS: [Synset('structure.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# year --> year.n.03
# the period of time that it takes for a planet (as, e.g., Earth or Mars) to make a complete revolution around the sun
# HYPERS: [Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# dominion --> dominion.n.03
# one of the self-governing nations in the British Commonwealth
# HYPERS: [Synset('state.n.04'), Synset('political_unit.n.01'), Synset('unit.n.03'), Synset('organization.n.01'), Synset('social_group.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# star --> star_topology.n.01
# the topology of a network whose components are connected to a hub
# HYPERS: [Synset('topology.n.04'), Synset('configuration.n.01'), Synset('design.n.02'), Synset('arrangement.n.03'), Synset('structure.n.03'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# soul --> soul.n.05
# a secular form of gospel that was a major Black musical genre in the 1960s and 1970s
# HYPERS: [Synset('black_music.n.01'), Synset('gospel.n.03'), Synset('music_genre.n.01'), Synset('folk_music.n.01'), Synset('expressive_style.n.01'), Synset('music.n.01'), Synset('popular_music.n.01'), Synset('communication.n.02'), Synset('auditory_communication.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bird --> shuttlecock.n.01
# badminton equipment consisting of a ball of cork or rubber with a crown of feathers
# HYPERS: [Synset('badminton_equipment.n.01'), Synset('sports_equipment.n.01'), Synset('equipment.n.01'), Synset('instrumentality.n.03'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# wing --> wing.n.07
# (in flight formation) a position to the side and just to the rear of another aircraft
# HYPERS: [Synset('position.n.01'), Synset('point.n.02'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# soil --> soil.n.02
# the part of the earth's surface consisting of humus and disintegrated rock
# HYPERS: [Synset('earth.n.02'), Synset('material.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
#
# image --> persona.n.02
# (Jungian psychology) a personal facade that one presents to the world
# HYPERS: [Synset('appearance.n.01'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# likeness --> likeness.n.02
# picture consisting of a graphic image of a person or thing
# HYPERS: [Synset('picture.n.01'), Synset('representation.n.02'), Synset('creation.n.02'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# fish --> pisces.n.01
# the twelfth sign of the zodiac; the sun is in this sign from about February 19 to March 20
# HYPERS: []
#
# food --> food.n.02
# any solid substance (as opposed to liquid) that is used as a source of nourishment
# HYPERS: [Synset('solid.n.01'), Synset('matter.n.03'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# work --> workplace.n.01
# a place where work is done
# HYPERS: [Synset('geographic_point.n.01'), Synset('point.n.02'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# generation --> generation.n.07
# the act of producing offspring or multiplying by such production
# HYPERS: [Synset('reproduction.n.05'), Synset('sexual_activity.n.01'), Synset('bodily_process.n.01'), Synset('organic_process.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# shrub --> shrub.n.01
# a low woody perennial plant usually having several major stems
# HYPERS: [Synset('woody_plant.n.01'), Synset('vascular_plant.n.01'), Synset('plant.n.02'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# dust --> dust.n.01
# fine powdery material such as dry earth or pollen that can be blown about in the air
# HYPERS: [Synset('particulate.n.01'), Synset('material.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
#
# breath --> breath.n.05
# a slight movement of the air
# HYPERS: [Synset('breeze.n.01'), Synset('wind.n.01'), Synset('weather.n.01'), Synset('atmospheric_phenomenon.n.01'), Synset('physical_phenomenon.n.01'), Synset('natural_phenomenon.n.01'), Synset('phenomenon.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# life --> liveliness.n.02
# animation and energy in action or expression
# HYPERS: [Synset('animation.n.03'), Synset('activeness.n.02'), Synset('trait.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# garden --> garden.n.02
# the flowers or vegetables or fruits or herbs that are cultivated in a garden
# HYPERS: [Synset('vegetation.n.01'), Synset('collection.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# food --> food.n.03
# anything that provides mental stimulus for thinking
# HYPERS: [Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# knowledge --> cognition.n.01
# the psychological result of perception and learning and reasoning
# HYPERS: [Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# head --> mind.n.01
# that which is responsible for one's thoughts and feelings; the seat of the faculty of reason
# HYPERS: [Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# name --> name.n.05
# by the sanction or authority of
# HYPERS: [Synset('sanction.n.04'), Synset('authorization.n.04'), Synset('management.n.01'), Synset('social_control.n.01'), Synset('group_action.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# gold --> gold.n.05
# something likened to the metal in brightness or preciousness or superiority etc.
# HYPERS: [Synset('invaluableness.n.01'), Synset('value.n.02'), Synset('worth.n.02'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# stone --> stone.n.11
# United States jurist who served on the United States Supreme Court as chief justice (1872-1946)
# HYPERS: []
#
# sleep --> sleep.n.02
# a torpid state resembling deep sleep
# HYPERS: [Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# side --> english.n.04
# (sports) the spin given to a ball by striking it on one side or releasing it with a sharp twist
# HYPERS: [Synset('spin.n.01'), Synset('rotation.n.03'), Synset('turning.n.04'), Synset('movement.n.03'), Synset('happening.n.01'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# flesh --> pulp.n.02
# a soft moist part of a fruit
# HYPERS: [Synset('plant_tissue.n.01'), Synset('plant_part.n.01'), Synset('natural_object.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# woman --> womanhood.n.02
# women as a class
# HYPERS: [Synset('class.n.03'), Synset('people.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bone --> bone.n.03
# a shade of white the color of bleached bones
# HYPERS: [Synset('white.n.02'), Synset('achromatic_color.n.01'), Synset('color.n.01'), Synset('visual_property.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# man --> world.n.08
# all of the living human inhabitants of the earth
# HYPERS: [Synset('group.n.01'), Synset('homo.n.02'), Synset('abstraction.n.06'), Synset('hominid.n.01'), Synset('entity.n.01'), Synset('primate.n.02'), Synset('placental.n.01'), Synset('mammal.n.01'), Synset('vertebrate.n.01'), Synset('chordate.n.01'), Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01')]
#
# father --> father.n.03
# `Father' is a term of address for priests in some churches (especially the Roman Catholic Church or the Orthodox Catholic Church); `Padre' is frequently used in the military
# HYPERS: [Synset('priest.n.01'), Synset('title.n.06'), Synset('clergyman.n.01'), Synset('holy_order.n.01'), Synset('appellation.n.01'), Synset('spiritual_leader.n.01'), Synset('status.n.01'), Synset('name.n.01'), Synset('leader.n.01'), Synset('state.n.02'), Synset('language_unit.n.01'), Synset('person.n.01'), Synset('attribute.n.02'), Synset('part.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('abstraction.n.06'), Synset('relation.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# mother --> mother.n.05
# a condition that is the inspiration for an activity or situation
# HYPERS: [Synset('inspiration.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# serpent --> snake.n.01
# limbless scaly elongate reptile; some are venomous
# HYPERS: [Synset('diapsid.n.01'), Synset('reptile.n.01'), Synset('vertebrate.n.01'), Synset('chordate.n.01'), Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# eye --> eye.n.01
# the organ of sight
# HYPERS: [Synset('sense_organ.n.01'), Synset('organ.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# desire --> desire.n.03
# something that is desired
# HYPERS: [Synset('arousal.n.02'), Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# fig --> libyan_islamic_fighting_group.n.01
# a Libyan terrorist group organized in 1995 and aligned with al-Qaeda; seeks to radicalize the Libyan government; attempted to assassinate Qaddafi
# HYPERS: []
#
# girdle --> girdle.n.02
# a band of material around the waist that strengthens a skirt or trousers
# HYPERS: [Synset('band.n.07'), Synset('strip.n.02'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# belly --> belly.n.05
# the underpart of the body of certain vertebrates such as snakes or fish
# HYPERS: [Synset('underpart.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# enmity --> hostility.n.03
# the feeling of a hostile person
# HYPERS: [Synset('hate.n.01'), Synset('emotion.n.01'), Synset('feeling.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# heel --> heel.n.05
# the lower end of a ship's mast
# HYPERS: [Synset('end.n.01'), Synset('extremity.n.04'), Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# son --> son.n.02
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# HYPERS: []
#
# thistle --> thistle.n.01
# any of numerous plants of the family Compositae and especially of the genera Carduus and Cirsium and Onopordum having prickly-edged leaves
# HYPERS: [Synset('weed.n.01'), Synset('vascular_plant.n.01'), Synset('plant.n.02'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# bread --> bread.n.01
# food made from dough of flour or meal and usually raised with yeast or baking powder and then baked
# HYPERS: [Synset('baked_goods.n.01'), Synset('starches.n.01'), Synset('food.n.02'), Synset('foodstuff.n.02'), Synset('solid.n.01'), Synset('food.n.01'), Synset('matter.n.03'), Synset('substance.n.07'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# tunic --> tunic.n.02
# any of a variety of loose fitting cloaks extending to the hips or knees
# HYPERS: [Synset('cloak.n.02'), Synset('overgarment.n.01'), Synset('garment.n.01'), Synset('clothing.n.01'), Synset('consumer_goods.n.01'), Synset('covering.n.02'), Synset('commodity.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# skin --> skin.n.06
# a bag serving as a container for liquids; it is made from the hide of an animal
# HYPERS: [Synset('bag.n.01'), Synset('container.n.01'), Synset('instrumentality.n.03'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# hand --> hand.n.13
# terminal part of the forelimb in certain vertebrates (e.g. apes or kangaroos)
# HYPERS: [Synset('forepaw.n.01'), Synset('paw.n.01'), Synset('animal_foot.n.01'), Synset('vertebrate_foot.n.01'), Synset('extremity.n.05'), Synset('external_body_part.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# cherub --> cherub.n.02
# an angel of the second order whose gift is knowledge; usually portrayed as a winged child
# HYPERS: [Synset('angel.n.01'), Synset('spiritual_being.n.01'), Synset('belief.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# way --> way.n.11
# a general category of things; used in the expression `in the way of'
# HYPERS: [Synset('category.n.02'), Synset('concept.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# brother --> buddy.n.01
# a close friend who accompanies his buddies in their activities
# HYPERS: [Synset('friend.n.01'), Synset('person.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# cattle --> cattle.n.01
# domesticated bovine animals as a group regardless of sex or age
# HYPERS: [Synset('bovine.n.01'), Synset('bovid.n.01'), Synset('ruminant.n.01'), Synset('even-toed_ungulate.n.01'), Synset('ungulate.n.01'), Synset('placental.n.01'), Synset('mammal.n.01'), Synset('vertebrate.n.01'), Synset('chordate.n.01'), Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# end --> goal.n.01
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
# HYPERS: [Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# fat --> adipose_tissue.n.01
# a kind of body tissue containing stored fat that serves as a source of energy; it also cushions and insulates vital organs
# HYPERS: [Synset('animal_tissue.n.01'), Synset('tissue.n.01'), Synset('body_part.n.01'), Synset('part.n.03'), Synset('thing.n.12'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# sin --> sine.n.01
# ratio of the length of the side opposite the given angle to the length of the hypotenuse of a right-angled triangle
# HYPERS: [Synset('trigonometric_function.n.01'), Synset('function.n.01'), Synset('mathematical_relation.n.01'), Synset('relation.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# blood --> blood.n.01
# the fluid (red in vertebrates) that is pumped through the body by the heart and contains plasma, blood cells, and platelets
# HYPERS: [Synset('liquid_body_substance.n.01'), Synset('body_substance.n.01'), Synset('substance.n.01'), Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
#
# mouth --> sass.n.01
# an impudent or insolent rejoinder
# HYPERS: [Synset('rejoinder.n.01'), Synset('reply.n.02'), Synset('speech_act.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# strength --> military_capability.n.01
# capability in terms of personnel and materiel that affect the capacity to fight a war
# HYPERS: [Synset('capability.n.01'), Synset('ability.n.01'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# sin --> sine.n.01
# ratio of the length of the side opposite the given angle to the length of the hypotenuse of a right-angled triangle
# HYPERS: [Synset('trigonometric_function.n.01'), Synset('function.n.01'), Synset('mathematical_relation.n.01'), Synset('relation.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# tent --> tent.n.02
# a web that resembles a tent or carpet
# HYPERS: [Synset('web.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# flute --> flute.n.03
# a groove or furrow in cloth etc (particularly a shallow concave groove on the shaft of a column)
# HYPERS: [Synset('groove.n.01'), Synset('depression.n.08'), Synset('concave_shape.n.01'), Synset('solid.n.03'), Synset('shape.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bronze --> bronze.n.02
# a sculpture made of bronze
# HYPERS: [Synset('sculpture.n.01'), Synset('plastic_art.n.01'), Synset('solid_figure.n.01'), Synset('art.n.01'), Synset('figure.n.06'), Synset('creation.n.02'), Synset('shape.n.02'), Synset('artifact.n.01'), Synset('attribute.n.02'), Synset('whole.n.02'), Synset('abstraction.n.06'), Synset('object.n.01'), Synset('entity.n.01'), Synset('physical_entity.n.01')]
#
# iron --> iron.n.04
# home appliance consisting of a flat metal base that is heated and used to smooth cloth
# HYPERS: [Synset('home_appliance.n.01'), Synset('appliance.n.02'), Synset('durables.n.01'), Synset('consumer_goods.n.01'), Synset('commodity.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# sister --> sister.n.03
# a female person who is a fellow member of a sorority or labor union or other group
# HYPERS: [Synset('member.n.01'), Synset('associate.n.01'), Synset('peer.n.01'), Synset('person.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# word --> word.n.07
# a word is a string of bits stored in computer memory
# HYPERS: [Synset('computer_memory_unit.n.01'), Synset('unit_of_measurement.n.01'), Synset('definite_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bruise --> bruise.n.01
# an injury that doesn't break the skin but results in some discoloration
# HYPERS: [Synset('injury.n.01'), Synset('ill_health.n.01'), Synset('pathological_state.n.01'), Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# boy --> boy.n.04
# (ethnic slur) offensive and disparaging term for Black man
# HYPERS: [Synset('black_man.n.01'), Synset('black.n.05'), Synset('man.n.01'), Synset('person.n.01'), Synset('person_of_color.n.01'), Synset('adult.n.01'), Synset('male.n.02'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# bruise --> bruise.n.01
# an injury that doesn't break the skin but results in some discoloration
# HYPERS: [Synset('injury.n.01'), Synset('ill_health.n.01'), Synset('pathological_state.n.01'), Synset('physical_condition.n.01'), Synset('condition.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# hundred --> hundred.n.01
# ten 10s
# HYPERS: [Synset('large_integer.n.01'), Synset('integer.n.01'), Synset('number.n.02'), Synset('definite_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# daughter --> daughter.n.01
# a female human offspring
# HYPERS: [Synset('female_offspring.n.01'), Synset('child.n.02'), Synset('female.n.02'), Synset('offspring.n.01'), Synset('person.n.01'), Synset('relative.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# giant --> giant_star.n.01
# a very bright star of large diameter and low density (relative to the Sun)
# HYPERS: [Synset('star.n.01'), Synset('celestial_body.n.01'), Synset('natural_object.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# evil --> evil.n.03
# the quality of being morally wrong in principle or practice
# HYPERS: [Synset('immorality.n.01'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# thought --> thinking.n.01
# the process of using your mind to consider something carefully
# HYPERS: [Synset('higher_cognitive_process.n.01'), Synset('process.n.02'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# heart --> kernel.n.03
# the choicest or most essential or most vital part of some idea or experience
# HYPERS: [Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# grace --> grace.n.07
# (Christian theology) the free and unmerited favor or beneficence of God
# HYPERS: [Synset('beneficence.n.02'), Synset('good.n.02'), Synset('morality.n.01'), Synset('quality.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# generation --> generation.n.03
# the normal time between successive generations
# HYPERS: [Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# violence --> violence.n.03
# a turbulent state resulting in injuries and destruction etc.
# HYPERS: [Synset('turbulence.n.03'), Synset('disorder.n.03'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# ark --> ark.n.02
# a boat built by Noah to save his family and animals from the flood
# HYPERS: [Synset('boat.n.01'), Synset('vessel.n.02'), Synset('craft.n.02'), Synset('vehicle.n.01'), Synset('conveyance.n.03'), Synset('instrumentality.n.03'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# nest --> nest.n.05
# furniture pieces made to fit close together
# HYPERS: [Synset('furniture.n.01'), Synset('furnishing.n.02'), Synset('instrumentality.n.03'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# house --> house.n.09
# the management of a gambling house or casino
# HYPERS: [Synset('management.n.02'), Synset('administration.n.02'), Synset('body.n.02'), Synset('social_group.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# cubit --> cubit.n.01
# an ancient unit of length based on the length of the forearm
# HYPERS: [Synset('linear_unit.n.01'), Synset('unit_of_measurement.n.01'), Synset('definite_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# length --> length.n.05
# a section of something that is long and narrow
# HYPERS: [Synset('section.n.04'), Synset('part.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# breadth --> width.n.01
# the extent of something from side to side
# HYPERS: [Synset('dimension.n.01'), Synset('magnitude.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# height --> stature.n.02
# (of a standing person) the distance from head to foot
# HYPERS: [Synset('bodily_property.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# side --> english.n.04
# (sports) the spin given to a ball by striking it on one side or releasing it with a sharp twist
# HYPERS: [Synset('spin.n.01'), Synset('rotation.n.03'), Synset('turning.n.04'), Synset('movement.n.03'), Synset('happening.n.01'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# covenant --> covenant.n.02
# (Bible) an agreement between God and his people in which God makes certain promises and requires certain behavior from them in return
# HYPERS: [Synset('agreement.n.01'), Synset('statement.n.01'), Synset('message.n.02'), Synset('communication.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# substance --> substance.n.01
# the real physical matter of which a person or thing consists
# HYPERS: [Synset('matter.n.03'), Synset('part.n.01'), Synset('physical_entity.n.01'), Synset('relation.n.01'), Synset('entity.n.01'), Synset('abstraction.n.06')]
#
# month --> month.n.02
# a time unit of approximately 30 days
# HYPERS: [Synset('time_unit.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# well --> well.n.04
# an open shaft through the floors of a building (as for a stairway)
# HYPERS: [Synset('shaft.n.08'), Synset('passageway.n.01'), Synset('passage.n.03'), Synset('way.n.06'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# rain --> rain.n.03
# anything happening rapidly or in quick successive
# HYPERS: [Synset('sequence.n.02'), Synset('temporal_arrangement.n.01'), Synset('temporal_property.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bird --> bird.n.02
# the flesh of a bird or fowl (wild or domestic) used as food
# HYPERS: [Synset('meat.n.01'), Synset('food.n.02'), Synset('solid.n.01'), Synset('matter.n.03'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# mountain --> mountain.n.01
# a land mass that projects well above its surroundings; higher than a hill
# HYPERS: [Synset('natural_elevation.n.01'), Synset('geological_formation.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# end --> goal.n.01
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
# HYPERS: [Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# window --> window.n.07
# an opening in a wall or screen that admits light and air and through which customers can be served
# HYPERS: [Synset('opening.n.10'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# raven --> raven.n.01
# large black bird with a straight bill and long wedge-shaped tail
# HYPERS: [Synset('corvine_bird.n.01'), Synset('oscine.n.01'), Synset('passerine.n.01'), Synset('bird.n.01'), Synset('vertebrate.n.01'), Synset('chordate.n.01'), Synset('animal.n.01'), Synset('organism.n.01'), Synset('living_thing.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# dove --> squab.n.01
# flesh of a pigeon suitable for roasting or braising; flesh of a dove (young squab) may be broiled
# HYPERS: [Synset('poultry.n.02'), Synset('bird.n.02'), Synset('meat.n.01'), Synset('food.n.02'), Synset('solid.n.01'), Synset('matter.n.03'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# foot --> metrical_foot.n.01
# (prosody) a group of 2 or 3 syllables forming the basic unit of poetic rhythm
# HYPERS: [Synset('meter.n.03'), Synset('poetic_rhythm.n.01'), Synset('versification.n.02'), Synset('form.n.10'), Synset('writing_style.n.01'), Synset('expressive_style.n.01'), Synset('communication.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# time --> time.n.06
# a person's experience on a particular occasion
# HYPERS: [Synset('experience.n.03'), Synset('happening.n.01'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# olive --> olive.n.04
# one-seeded fruit of the European olive tree usually pickled and used as a relish
# HYPERS: [Synset('drupe.n.01'), Synset('relish.n.02'), Synset('fruit.n.01'), Synset('condiment.n.01'), Synset('reproductive_structure.n.01'), Synset('flavorer.n.01'), Synset('plant_organ.n.01'), Synset('ingredient.n.03'), Synset('plant_part.n.01'), Synset('foodstuff.n.02'), Synset('natural_object.n.01'), Synset('food.n.01'), Synset('whole.n.02'), Synset('substance.n.07'), Synset('object.n.01'), Synset('matter.n.03'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# covering --> covering.n.04
# the act of protecting something by covering it
# HYPERS: [Synset('protection.n.01'), Synset('activity.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# altar --> altar.n.02
# a raised structure on which gifts or sacrifices to a god are made
# HYPERS: [Synset('structure.n.01'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# youth --> youth.n.06
# the freshness and vitality characteristic of a young person
# HYPERS: [Synset('youngness.n.01'), Synset('age.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# harvest --> harvest.n.04
# the season for gathering crops
# HYPERS: [Synset('season.n.02'), Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# heat --> hotness.n.01
# the presence of heat
# HYPERS: [Synset('temperature.n.01'), Synset('fundamental_quantity.n.01'), Synset('physical_property.n.01'), Synset('measure.n.02'), Synset('property.n.02'), Synset('abstraction.n.06'), Synset('attribute.n.02'), Synset('entity.n.01')]
#
# summer --> summer.n.01
# the warmest season of the year; in the northern hemisphere it extends from the summer solstice to the autumnal equinox
# HYPERS: [Synset('season.n.02'), Synset('time_period.n.01'), Synset('fundamental_quantity.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# fear --> fear.n.03
# a feeling of profound respect for someone or something
# HYPERS: [Synset('emotion.n.01'), Synset('feeling.n.01'), Synset('state.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# fish --> pisces.n.02
# (astrology) a person who is born while the sun is in Pisces
# HYPERS: [Synset('person.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# bow --> bow.n.09
# a stroke with a curved piece of wood with taut horsehair strands that is used in playing stringed instruments
# HYPERS: [Synset('stroke.n.12'), Synset('motion.n.03'), Synset('change.n.03'), Synset('action.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# cloud --> swarm.n.02
# a group of many things in the air or on the ground
# HYPERS: [Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# vineyard --> vineyard.n.01
# a farm of grapevines where wine grapes are produced
# HYPERS: [Synset('farm.n.01'), Synset('workplace.n.01'), Synset('geographic_point.n.01'), Synset('point.n.02'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# wine --> wine.n.02
# a red as dark as red wine
# HYPERS: [Synset('dark_red.n.01'), Synset('red.n.01'), Synset('chromatic_color.n.01'), Synset('color.n.01'), Synset('visual_property.n.01'), Synset('property.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# nakedness --> openness.n.02
# characterized by an attitude of ready accessibility (especially about one's actions or purposes); without concealment; not secretive
# HYPERS: [Synset('sociability.n.01'), Synset('sociality.n.01'), Synset('nature.n.04'), Synset('trait.n.01'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# shoulder --> shoulder.n.05
# a narrow edge of land (usually unpaved) along the side of a road
# HYPERS: [Synset('edge.n.06'), Synset('limit.n.04'), Synset('boundary.n.01'), Synset('extremity.n.04'), Synset('region.n.01'), Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# servant --> servant.n.01
# a person working in the service of another (especially in the household)
# HYPERS: [Synset('worker.n.01'), Synset('person.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# people --> people.n.03
# members of a family line
# HYPERS: [Synset('family.n.04'), Synset('lineage.n.01'), Synset('genealogy.n.01'), Synset('kin.n.02'), Synset('social_group.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# tongue --> tongue.n.07
# the flap of material under the laces of a shoe or boot
# HYPERS: [Synset('flap.n.01'), Synset('covering.n.02'), Synset('artifact.n.01'), Synset('whole.n.02'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# hunting --> search.n.01
# the activity of looking thoroughly in order to find something or someone
# HYPERS: [Synset('activity.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# kingdom --> kingdom.n.06
# a basic group of natural objects
# HYPERS: [Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# seat --> seat.n.07
# the legal right to sit as a member in a legislative or similar body
# HYPERS: [Synset('legal_right.n.01'), Synset('right.n.01'), Synset('abstraction.n.01'), Synset('concept.n.01'), Synset('idea.n.01'), Synset('content.n.05'), Synset('cognition.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# lip --> lip.n.05
# either the outer margin or the inner margin of the aperture of a gastropod's shell
# HYPERS: [Synset('margin.n.01'), Synset('boundary.n.02'), Synset('line.n.04'), Synset('shape.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# word --> son.n.02
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# HYPERS: []
#
# valley --> valley.n.01
# a long depression in the surface of the land that usually contains a river
# HYPERS: [Synset('natural_depression.n.01'), Synset('geological_formation.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# brick --> brick.n.02
# a good fellow; helpful and trustworthy
# HYPERS: [Synset('good_person.n.01'), Synset('person.n.01'), Synset('causal_agent.n.01'), Synset('organism.n.01'), Synset('physical_entity.n.01'), Synset('living_thing.n.01'), Synset('entity.n.01'), Synset('whole.n.02'), Synset('object.n.01')]
#
# burning --> combustion.n.01
# a process in which a substance reacts with oxygen to give heat and light
# HYPERS: [Synset('oxidation.n.01'), Synset('chemical_reaction.n.01'), Synset('chemical_process.n.01'), Synset('natural_process.n.01'), Synset('process.n.06'), Synset('physical_entity.n.01'), Synset('entity.n.01')]
#
# clay --> clay.n.04
# United States politician responsible for the Missouri Compromise between free and slave states (1777-1852)
# HYPERS: []
#
# tower --> column.n.04
# anything that approximates the shape of a column or tower
# HYPERS: [Synset('shape.n.02'), Synset('attribute.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# people --> people.n.03
# members of a family line
# HYPERS: [Synset('family.n.04'), Synset('lineage.n.01'), Synset('genealogy.n.01'), Synset('kin.n.02'), Synset('social_group.n.01'), Synset('group.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# bride --> bridget.n.01
# Irish abbess; a patron saint of Ireland (453-523)
# HYPERS: []
#
# blessing --> grace.n.06
# a short prayer of thanks before a meal
# HYPERS: [Synset('prayer.n.02'), Synset('request.n.02'), Synset('speech_act.n.01'), Synset('act.n.02'), Synset('event.n.01'), Synset('psychological_feature.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01')]
#
# south --> south.n.04
# a location in the southern part of a country, region, or city
# HYPERS: [Synset('location.n.01'), Synset('object.n.01'), Synset('physical_entity.n.01'), Synset('entity.n.01')]

# %%
wn.synset('living_thing.n.01').definition()
# Out:
# 'a living (or once living) entity'

# %% [markdown]
# # 5. test the hypernyms for each sense to create the categories
#
# Look up all hypernyms in the path to the terminal node of a given sense. Then look for certain qualities in the path that would lend one of 4 categories:
# 1. object
# 2. agent (living)
# 3. location (place)
# 4. time*
#
# The categories are created through a process of elimination, as applied below...

# %%
lexToSynset = dict( (lex, mappedToSynset[lex]['synset']) for lex in mappedToSynset )

# %%
accountedFor = set()
catRules = {('time','point'): {'point.n.06','measure.'},
            ('time','period') : {'time_period.n.01'},
            ('time','unit') : {'time_unit.n.01'},
            ('time','tense') : {'tense.n.01'},
            ('place','boundary') : {'region.n.01', 'boundary.n.01'},
            ('place','point'): {'location.n.01','point.n.02'},
            ('place','location') : {'region.n.01','location.n.01'},
            ('place','location','general') : {'location.n.01'},
            ('place','region') : {'region.n.03'},
            ('place','biome') : {'biome.n.01'},
            ('place','geological formation') : {'geological_formation.n.01'},
            ('place','body of water') : {'body_of_water.n.01'},
            ('place','position') : {'position.n.07'},
            ('agency','unit') : {'unit.n.03'},
            ('agency','group') : {'people.n.01'},
            ('agency','living') : {'living_thing.n.01'},
            ('agency','social group') : {'social_group.n.01'},
            ('agency','biological group') : {'biological_group.n.01'},
            ('object','body part') : {'body_part.n.01'},
            ('object','abstract', 'state') : {'state.n.02','condition.n.01'},
            ('object','abstract','state of mind') : {'cognitive_state.n.01'},
            ('object','abstract','mental feature') : {'psychological_feature.n.01'},
            ('object','abstract','attribute') : {'property.n.02'},
            ('object','abstract','expression') : {'expression.n.01'},
            ('object','physical','man-made') : {'artifact.n.01'},
            ('object','abstract','unit') : {'unit.n.04'},
            ('object','abstract','unit2') : {'unit_of_measurement.n.01'},
            ('object', 'abstract', 'measure') : {'measure.n.02'},
            ('object','abstract','idea') : {'idea.n.01'},
            ('object','abstract','structure') : {'structure.n.03'},
            ('object','physical','substance') : {'substance.n.01'},
            ('object','physical','substance2') : {'substance.n.07'},
            ('object','physical','solid') : {'solid.n.01'},
            ('object','physical','plant') : {'plant.n.02'},
            ('object','physical','plant in locale'): {'vegetation.n.01'},
            ('object','abstract','phenomenon in atmosphere') : {'atmospheric_phenomenon.n.01'},
            ('object','physical','nature') : {'natural_object.n.01'},
            ('object','physical','possession') : {'possession.n.02'},
            ('object','abstract','communication') : {'communication.n.02'},
            ('object','abstract','quantity') : {'indefinite_quantity.n.01'},
            ('object','abstract','motion') : {'mechanical_phenomenon.n.01'},
            ('object','abstract','phenomenon') : {'phenomenon.n.01'},
            ('object','abstract','process'):{'process.n.06'},
            ('object','physical','part') : {'part.n.02'},
           } 
for lex, synset in lexToSynset.items():
    hypernyms = set(h.name() for h in synset.closure(hyper))
    for cat, rule in catRules.items():
        if len(hypernyms & rule) == len(rule):
            accountedFor.add(lex)

# %%
print('accounted for: {}/{}'.format( 
      len(accountedFor & set(lexToSynset.keys())),
      len(lexToSynset.keys())
     ))
# Out:
# accounted for: 1130/1306

# %%
for lex in set(lexToSynset.keys()) - accountedFor:
    print(lexToSynset[lex])
    print(mappedToSynset[lex]['synset'].definition())
    print(list((x.name(), x.definition()) for x in mappedToSynset[lex]['synset'].closure(hyper)))
    print()
# Out:
# Synset('pile.n.01')
# a collection of objects laid on top of each other
# [('collection.n.01', 'several things grouped together or considered as a whole'), ('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sine.n.01')
# ratio of the length of the side opposite the given angle to the length of the hypotenuse of a right-angled triangle
# [('trigonometric_function.n.01', 'function of an angle expressed as a ratio of the length of the sides of right-angled triangle containing the angle'), ('function.n.01', '(mathematics) a mathematical relation such that each element of a given set (the domain of the function) is associated with an element of another set (the range of the function)'), ('mathematical_relation.n.01', 'a relation between mathematical expressions (such as equality or inequality)'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('greatness.n.01')
# the property possessed by something or someone of outstanding importance or eminence
# [('importance.n.01', 'the quality of being important and worthy of note'), ('value.n.02', 'the quality (positive or negative) that renders something desirable or valuable'), ('worth.n.02', 'the quality that renders something desirable or valuable or useful'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sin.n.01')
# estrangement from god
# [('unrighteousness.n.01', 'failure to adhere to moral principles'), ('immorality.n.01', 'the quality of not being in accord with standards of right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('hope.n.02')
# the general feeling that some desire will be fulfilled
# [('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('anguish.n.02')
# extreme distress of body or mind
# [('distress.n.02', 'a state of adversity (danger or affliction or need)'), ('adversity.n.01', 'a state of misfortune or affliction'), ('misfortune.n.02', 'an unfortunate state resulting from unfavorable outcomes'), ('fortune.n.04', 'your overall circumstances or condition in life (including everything that happens to you)'), ('condition.n.03', 'a mode of being or form of existence of a person or thing'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('tent.n.02')
# a web that resembles a tent or carpet
# [('web.n.01', 'an intricate network suggesting something that was formed by weaving or interweaving'), ('object.n.01', 'a tangible and visible entity; an entity that can cast a shadow'), ('physical_entity.n.01', 'an entity that has physical existence'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('flute.n.03')
# a groove or furrow in cloth etc (particularly a shallow concave groove on the shaft of a column)
# [('groove.n.01', 'a long narrow furrow cut either by a natural process (such as erosion) or by a tool (as e.g. a groove in a phonograph record)'), ('depression.n.08', 'a concavity in a surface produced by pressing'), ('concave_shape.n.01', 'a shape that curves or bends inward'), ('solid.n.03', 'a three-dimensional shape'), ('shape.n.02', 'the spatial arrangement of something as distinct from its substance'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('greatness.n.01')
# the property possessed by something or someone of outstanding importance or eminence
# [('importance.n.01', 'the quality of being important and worthy of note'), ('value.n.02', 'the quality (positive or negative) that renders something desirable or valuable'), ('worth.n.02', 'the quality that renders something desirable or valuable or useful'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('grief.n.01')
# intense sorrow caused by loss of a loved one (especially by death)
# [('sorrow.n.01', 'an emotion of great sadness associated with loss or bereavement'), ('sadness.n.01', 'emotions experienced when not in a state of well-being'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('determination.n.02')
# the quality of being determined to do or achieve something; firmness of purpose
# [('resoluteness.n.01', 'the trait of being resolute'), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('oppression.n.02')
# the state of being kept down by unjust use of force or authority: "after years of oppression they finally revolted"
# [('subjugation.n.01', 'forced submission to control by others'), ('relationship.n.03', 'a state involving mutual dealings between people or parties or countries'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('putrescence.n.02')
# the quality of rotting and becoming putrid
# [('unwholesomeness.n.01', 'the quality of being unhealthful and generally bad for you'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('milk.n.03')
# a river that rises in the Rockies in northwestern Montana and flows eastward to become a tributary of the Missouri River
# []
#
# Synset('hope.n.06')
# one of the three Christian virtues
# [('theological_virtue.n.01', 'according to Christian ethics: one of the three virtues (faith, hope, and charity) created by God to round out the natural virtues'), ('cardinal_virtue.n.01', 'one of the seven preeminent virtues'), ('virtue.n.04', 'a particular moral excellence'), ('good.n.02', 'moral excellence or admirableness'), ('morality.n.01', 'concern with the distinction between good and evil or right and wrong; right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wall.n.02')
# anything that suggests a wall in structure or function or effect
# [('object.n.01', 'a tangible and visible entity; an entity that can cast a shadow'), ('physical_entity.n.01', 'an entity that has physical existence'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('snow.n.03')
# English writer of novels about moral dilemmas in academe (1905-1980)
# []
#
# Synset('part.n.02')
# something less than the whole of a human artifact
# [('object.n.01', 'a tangible and visible entity; an entity that can cast a shadow'), ('physical_entity.n.01', 'an entity that has physical existence'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('profit.n.02')
# the advantageous quality of being beneficial
# [('advantage.n.01', 'the quality of having a superior or more favorable position'), ('asset.n.01', 'a useful or valuable quality'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wish.n.01')
# a specific feeling of desire
# [('desire.n.01', 'the feeling that accompanies an unsatisfied state'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('key.n.07')
# United States lawyer and poet who wrote a poem after witnessing the British attack on Baltimore during the War of 1812; the poem was later set to music and entitled `The Star-Spangled Banner' (1779-1843)
# []
#
# Synset('slumber.n.02')
# a dormant or quiescent state
# [('dormancy.n.01', 'a state of quiet (but possibly temporary) inaction'), ('inaction.n.01', 'the state of being inactive'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('greatness.n.01')
# the property possessed by something or someone of outstanding importance or eminence
# [('importance.n.01', 'the quality of being important and worthy of note'), ('value.n.02', 'the quality (positive or negative) that renders something desirable or valuable'), ('worth.n.02', 'the quality that renders something desirable or valuable or useful'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wrinkle.n.01')
# a slight depression in the smoothness of a surface
# [('depression.n.08', 'a concavity in a surface produced by pressing'), ('concave_shape.n.01', 'a shape that curves or bends inward'), ('solid.n.03', 'a three-dimensional shape'), ('shape.n.02', 'the spatial arrangement of something as distinct from its substance'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wood.n.06')
# United States painter noted for works based on life in the Midwest (1892-1942)
# []
#
# Synset('proportion.n.04')
# the relation between things (or parts of things) with respect to their comparative quantity, magnitude, or degree
# [('magnitude_relation.n.01', 'a relation between magnitudes'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('solution.n.04')
# the set of values that give a true statement when substituted into an equation
# [('set.n.02', '(mathematics) an abstract collection of numbers or symbols'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('stubbornness.n.02')
# resolute adherence to your own ideas or desires
# [('resoluteness.n.01', 'the trait of being resolute'), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('self-control.n.02')
# the trait of resolutely controlling your own behavior
# [('resoluteness.n.01', 'the trait of being resolute'), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('enslavement.n.01')
# the state of being a slave
# [('subjugation.n.01', 'forced submission to control by others'), ('relationship.n.03', 'a state involving mutual dealings between people or parties or countries'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('strength.n.08')
# the condition of financial success
# [('prosperity.n.02', 'the condition of prospering; having good fortune'), ('good_fortune.n.01', 'an auspicious state resulting from favorable outcomes'), ('fortune.n.04', 'your overall circumstances or condition in life (including everything that happens to you)'), ('condition.n.03', 'a mode of being or form of existence of a person or thing'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('evil.n.03')
# the quality of being morally wrong in principle or practice
# [('immorality.n.01', 'the quality of not being in accord with standards of right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('grace.n.07')
# (Christian theology) the free and unmerited favor or beneficence of God
# [('beneficence.n.02', 'the quality of being kind or helpful or generous'), ('good.n.02', 'moral excellence or admirableness'), ('morality.n.01', 'concern with the distinction between good and evil or right and wrong; right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('integrity.n.02')
# moral soundness
# [('honesty.n.01', 'the quality of being honest'), ('righteousness.n.01', 'adhering to moral principles'), ('morality.n.01', 'concern with the distinction between good and evil or right and wrong; right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('enslavement.n.01')
# the state of being a slave
# [('subjugation.n.01', 'forced submission to control by others'), ('relationship.n.03', 'a state involving mutual dealings between people or parties or countries'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('avail.n.01')
# a means of serving
# [('helpfulness.n.01', 'the property of providing useful assistance'), ('utility.n.02', 'the quality of being of practical use'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('violence.n.03')
# a turbulent state resulting in injuries and destruction etc.
# [('turbulence.n.03', 'a state of violent disturbance and disorder (as in politics or social conditions generally)'), ('disorder.n.03', 'a disturbance of the peace or of public order'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('oppression.n.02')
# the state of being kept down by unjust use of force or authority: "after years of oppression they finally revolted"
# [('subjugation.n.01', 'forced submission to control by others'), ('relationship.n.03', 'a state involving mutual dealings between people or parties or countries'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('perversity.n.02')
# deliberately deviating from what is good
# [('evil.n.03', 'the quality of being morally wrong in principle or practice'), ('immorality.n.01', 'the quality of not being in accord with standards of right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('pile.n.01')
# a collection of objects laid on top of each other
# [('collection.n.01', 'several things grouped together or considered as a whole'), ('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('homer.n.04')
# United States painter best known for his seascapes (1836-1910)
# []
#
# Synset('swarm.n.02')
# a group of many things in the air or on the ground
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('substance.n.01')
# the real physical matter of which a person or thing consists
# [('matter.n.03', 'that which has mass and occupies space'), ('part.n.01', 'something determined in relation to something that includes it'), ('physical_entity.n.01', 'an entity that has physical existence'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples')]
#
# Synset('swarm.n.02')
# a group of many things in the air or on the ground
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sine.n.01')
# ratio of the length of the side opposite the given angle to the length of the hypotenuse of a right-angled triangle
# [('trigonometric_function.n.01', 'function of an angle expressed as a ratio of the length of the sides of right-angled triangle containing the angle'), ('function.n.01', '(mathematics) a mathematical relation such that each element of a given set (the domain of the function) is associated with an element of another set (the range of the function)'), ('mathematical_relation.n.01', 'a relation between mathematical expressions (such as equality or inequality)'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('fear.n.03')
# a feeling of profound respect for someone or something
# [('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sin.n.01')
# estrangement from god
# [('unrighteousness.n.01', 'failure to adhere to moral principles'), ('immorality.n.01', 'the quality of not being in accord with standards of right or good conduct'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('lot.n.07')
# (Old Testament) nephew of Abraham; God destroyed Sodom and Gomorrah but chose to spare Lot and his family who were told to flee without looking back at the destruction
# []
#
# Synset('mourning.n.01')
# state of sorrow over the death or departure of a loved one
# [('sadness.n.02', 'the state of being sad'), ('unhappiness.n.02', 'state characterized by emotions ranging from mild discontentment to deep grief'), ('emotional_state.n.01', "the state of a person's emotions (especially with regard to pleasure or dejection)"), ('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('mourning.n.01')
# state of sorrow over the death or departure of a loved one
# [('sadness.n.02', 'the state of being sad'), ('unhappiness.n.02', 'state characterized by emotions ranging from mild discontentment to deep grief'), ('emotional_state.n.01', "the state of a person's emotions (especially with regard to pleasure or dejection)"), ('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('death.n.06')
# the personification of death
# []
#
# Synset('infidelity.n.01')
# the quality of being unfaithful
# [('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('south.n.01')
# the region of the United States lying to the south of the Mason-Dixon line
# []
#
# Synset('porter.n.05')
# United States writer of short stories whose pen name was O. Henry (1862-1910)
# []
#
# Synset('oppression.n.02')
# the state of being kept down by unjust use of force or authority: "after years of oppression they finally revolted"
# [('subjugation.n.01', 'forced submission to control by others'), ('relationship.n.03', 'a state involving mutual dealings between people or parties or countries'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('tongue.n.03')
# any long thin projection that is transient
# [('projection.n.05', 'any solid convex shape that juts out from something'), ('convex_shape.n.01', 'a shape that curves or bulges outward'), ('solid.n.03', 'a three-dimensional shape'), ('shape.n.02', 'the spatial arrangement of something as distinct from its substance'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('prison.n.02')
# a prisonlike situation; a place of seeming confinement
# [('situation.n.01', 'the general state of things; the combination of circumstances at a given time'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('fear.n.03')
# a feeling of profound respect for someone or something
# [('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sand.n.02')
# French writer known for works concerning women's rights and independence (1804-1876)
# []
#
# Synset('profit.n.02')
# the advantageous quality of being beneficial
# [('advantage.n.01', 'the quality of having a superior or more favorable position'), ('asset.n.01', 'a useful or valuable quality'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('swarm.n.02')
# a group of many things in the air or on the ground
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('son.n.02')
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# []
#
# Synset('rage.n.04')
# violent state of the elements
# [('violence.n.03', 'a turbulent state resulting in injuries and destruction etc.'), ('turbulence.n.03', 'a state of violent disturbance and disorder (as in politics or social conditions generally)'), ('disorder.n.03', 'a disturbance of the peace or of public order'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('persuasiveness.n.01')
# the power to induce the taking of a course of action or the embracing of a point of view by means of argument or entreaty
# [('power.n.01', 'possession of controlling influence'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('dunghill.n.02')
# a heap of dung or refuse
# [('pile.n.01', 'a collection of objects laid on top of each other'), ('collection.n.01', 'several things grouped together or considered as a whole'), ('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('openness.n.02')
# characterized by an attitude of ready accessibility (especially about one's actions or purposes); without concealment; not secretive
# [('sociability.n.01', "the relative tendency or disposition to be sociable or associate with one's fellows"), ('sociality.n.01', 'the tendency to associate with others and to form social groups'), ('nature.n.04', "the complex of emotional and intellectual attributes that determine a person's characteristic actions and reactions"), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('life.n.03')
# the course of existence of an individual; the actions and events that occur in living
# [('being.n.01', 'the state or fact of existing'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('stream.n.04')
# something that resembles a flowing stream in moving continuously
# [('motion.n.04', 'a state of change'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('cleft.n.01')
# a split or indentation in something (as the palate or chin)
# [('indentation.n.01', 'a concave cut into a surface or edge (as in a coastline)'), ('concave_shape.n.01', 'a shape that curves or bends inward'), ('solid.n.03', 'a three-dimensional shape'), ('shape.n.02', 'the spatial arrangement of something as distinct from its substance'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('hero.n.04')
# Greek mathematician and inventor who devised a way to determine the area of a triangle and who described various mechanical devices (first century)
# []
#
# Synset('trust.n.03')
# the trait of believing in the honesty and reliability of others
# [('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('clay.n.04')
# United States politician responsible for the Missouri Compromise between free and slave states (1777-1852)
# []
#
# Synset('widowhood.n.02')
# the state of being a widow who has not remarried
# [('marital_status.n.01', 'the condition of being married or unmarried'), ('legal_status.n.01', 'a status defined by law'), ('status.n.01', 'the relative position or standing of things or especially persons in a society'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('shaking.n.02')
# a shaky motion
# [('motion.n.04', 'a state of change'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('depth.n.06')
# the attribute or quality of being deep, strong, or intense
# [('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('virgo.n.03')
# the sixth sign of the zodiac; the sun is in this sign from about August 23 to September 22
# []
#
# Synset('kingdom.n.06')
# a basic group of natural objects
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('prison.n.02')
# a prisonlike situation; a place of seeming confinement
# [('situation.n.01', 'the general state of things; the combination of circumstances at a given time'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('humility.n.01')
# a disposition to be humble; a lack of false pride
# [('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('pile.n.01')
# a collection of objects laid on top of each other
# [('collection.n.01', 'several things grouped together or considered as a whole'), ('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('rejoicing.n.01')
# a feeling of great happiness
# [('happiness.n.02', 'emotions experienced when in a state of well-being'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('reed.n.02')
# United States journalist who reported on the October Revolution from Petrograd in 1917; founded the Communist Labor Party in America in 1919; is buried in the Kremlin in Moscow (1887-1920)
# []
#
# Synset('root.n.03')
# (linguistics) the form of a word after all affixes are removed
# [('form.n.01', 'the phonological or orthographic sound or appearance of a word that can be used to describe or identify something'), ('word.n.01', 'a unit of language that native speakers can identify'), ('language_unit.n.01', 'one of the natural units into which linguistic messages can be analyzed'), ('part.n.01', 'something determined in relation to something that includes it'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('time.n.05')
# the continuum of experience in which events pass from the future through the present to the past
# [('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('kingdom.n.06')
# a basic group of natural objects
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('east.n.03')
# the region of the United States lying to the north of the Ohio River and to the east of the Mississippi River
# []
#
# Synset('loathsomeness.n.01')
# the quality of being disgusting to the senses or emotions
# [('offensiveness.n.01', 'the quality of being offensive'), ('unpleasantness.n.02', 'the quality of giving displeasure'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wisdom_of_solomon.n.01')
# an Apocryphal book consisting mainly of a meditation on wisdom; although ascribed to Solomon it was probably written in the first century BC
# []
#
# Synset('horror.n.01')
# intense and profound fear
# [('fear.n.01', 'an emotion experienced in anticipation of some specific pain or danger (usually accompanied by a desire to flee or fight)'), ('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('gold.n.05')
# something likened to the metal in brightness or preciousness or superiority etc.
# [('invaluableness.n.01', 'the positive quality of being precious and beyond value'), ('value.n.02', 'the quality (positive or negative) that renders something desirable or valuable'), ('worth.n.02', 'the quality that renders something desirable or valuable or useful'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('recess.n.02')
# a small concavity
# [('concave_shape.n.01', 'a shape that curves or bends inward'), ('solid.n.03', 'a three-dimensional shape'), ('shape.n.02', 'the spatial arrangement of something as distinct from its substance'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('lot.n.07')
# (Old Testament) nephew of Abraham; God destroyed Sodom and Gomorrah but chose to spare Lot and his family who were told to flee without looking back at the destruction
# []
#
# Synset('shame.n.02')
# a state of dishonor
# [('dishonor.n.01', 'a state of shame or disgrace'), ('standing.n.01', 'social or financial or professional status or reputation'), ('status.n.01', 'the relative position or standing of things or especially persons in a society'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('tree.n.03')
# English actor and theatrical producer noted for his lavish productions of Shakespeare (1853-1917)
# []
#
# Synset('god.n.01')
# the supernatural being conceived as the perfect and omnipotent and omniscient originator and ruler of the universe; the object of worship in monotheistic religions
# []
#
# Synset('son.n.02')
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# []
#
# Synset('lip.n.05')
# either the outer margin or the inner margin of the aperture of a gastropod's shell
# ...
#
# Synset('stone.n.11')
# United States jurist who served on the United States Supreme Court as chief justice (1872-1946)
# []
#
# Synset('male.n.03')
# the capital of Maldives in the center of the islands
# []
#
# Synset('forlornness.n.01')
# sadness resulting from being forsaken or abandoned
# [('sadness.n.01', 'emotions experienced when not in a state of well-being'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('war.n.02')
# a legal state created by a declaration of war and ended by official declaration during which the international rules of war apply
# [('hostility.n.02', 'a state of deep-seated ill-will'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('kingdom.n.06')
# a basic group of natural objects
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('image.n.07')
# (mathematics) the set of values of the dependent variable for which a function is defined
# [('set.n.02', '(mathematics) an abstract collection of numbers or symbols'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('strategic_arms_limitation_talks.n.01')
# negotiations between the United States and the Union of Soviet Socialist Republics opened in 1969 in Helsinki designed to limit both countries' stock of nuclear weapons
# []
#
# Synset('traffic.n.01')
# the aggregation of things (pedestrians or vehicles) coming and going in a particular locality during a specified period of time
# [('collection.n.01', 'several things grouped together or considered as a whole'), ('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('greenwich_village.n.01')
# a mainly residential district of Manhattan; `the Village' became a home for many writers and artists in the 20th century
# []
#
# Synset('nation.n.03')
# United States prohibitionist who raided saloons and destroyed bottles of liquor with a hatchet (1846-1911)
# []
#
# Synset('sickness.n.02')
# defectiveness or unsoundness
# [('defectiveness.n.01', 'the state of being defective'), ('imperfection.n.01', 'the state or an instance of being imperfect'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('violence.n.03')
# a turbulent state resulting in injuries and destruction etc.
# [('turbulence.n.03', 'a state of violent disturbance and disorder (as in politics or social conditions generally)'), ('disorder.n.03', 'a disturbance of the peace or of public order'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('farmer.n.03')
# an expert on cooking whose cookbook has undergone many editions (1857-1915)
# []
#
# Synset('flint.n.02')
# a river in western Georgia that flows generally south to join the Chattahoochee River at the Florida border where they form the Apalachicola River
# []
#
# Synset('gold.n.05')
# something likened to the metal in brightness or preciousness or superiority etc.
# [('invaluableness.n.01', 'the positive quality of being precious and beyond value'), ('value.n.02', 'the quality (positive or negative) that renders something desirable or valuable'), ('worth.n.02', 'the quality that renders something desirable or valuable or useful'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('rest.n.05')
# euphemisms for death (based on an analogy between lying in a bed and in a tomb)
# [('death.n.03', 'the absence of life or state of being dead'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('son.n.02')
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# []
#
# Synset('shame.n.02')
# a state of dishonor
# [('dishonor.n.01', 'a state of shame or disgrace'), ('standing.n.01', 'social or financial or professional status or reputation'), ('status.n.01', 'the relative position or standing of things or especially persons in a society'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('pleasure.n.01')
# a fundamental feeling that is hard to define but that people desire to experience
# [('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('libyan_islamic_fighting_group.n.01')
# a Libyan terrorist group organized in 1995 and aligned with al-Qaeda; seeks to radicalize the Libyan government; attempted to assassinate Qaddafi
# []
#
# Synset('reproach.n.02')
# disgrace or shame
# [('shame.n.02', 'a state of dishonor'), ('dishonor.n.01', 'a state of shame or disgrace'), ('standing.n.01', 'social or financial or professional status or reputation'), ('status.n.01', 'the relative position or standing of things or especially persons in a society'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('tenth.n.02')
# position ten in a countable series of things
# [('rank.n.02', 'relative status'), ('status.n.01', 'the relative position or standing of things or especially persons in a society'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('obedience.n.02')
# the trait of being willing to obey
# [('tractability.n.01', 'the trait of being easily persuaded'), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('self-control.n.02')
# the trait of resolutely controlling your own behavior
# [('resoluteness.n.01', 'the trait of being resolute'), ('trait.n.01', 'a distinguishing feature of your personal nature'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('hostility.n.03')
# the feeling of a hostile person
# [('hate.n.01', 'the emotion of intense dislike; a feeling of dislike so strong that it demands action'), ('emotion.n.01', 'any strong feeling'), ('feeling.n.01', 'the experiencing of affective and emotional states'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('capricorn.n.03')
# the tenth sign of the zodiac; the sun is in this sign from about December 22 to January 19
# []
#
# Synset('son.n.02')
# the divine word of God; the second person in the Trinity (incarnate in Jesus)
# []
#
# Synset('wall.n.02')
# anything that suggests a wall in structure or function or effect
# [('object.n.01', 'a tangible and visible entity; an entity that can cast a shadow'), ('physical_entity.n.01', 'an entity that has physical existence'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('wisdom_of_solomon.n.01')
# an Apocryphal book consisting mainly of a meditation on wisdom; although ascribed to Solomon it was probably written in the first century BC
# []
#
# Synset('greenwich_village.n.01')
# a mainly residential district of Manhattan; `the Village' became a home for many writers and artists in the 20th century
# []
#
# Synset('prison.n.02')
# a prisonlike situation; a place of seeming confinement
# [('situation.n.01', 'the general state of things; the combination of circumstances at a given time'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('property.n.05')
# any movable articles or objects used on the set of a play or movie
# [('object.n.01', 'a tangible and visible entity; an entity that can cast a shadow'), ('physical_entity.n.01', 'an entity that has physical existence'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('tree.n.03')
# English actor and theatrical producer noted for his lavish productions of Shakespeare (1853-1917)
# []
#
# Synset('chain.n.07')
# British biochemist (born in Germany) who isolated and purified penicillin, which had been discovered in 1928 by Sir Alexander Fleming (1906-1979)
# []
#
# Synset('setting.n.02')
# the state of the environment in which a situation exists
# [('environment.n.01', 'the totality of surrounding conditions'), ('situation.n.01', 'the general state of things; the combination of circumstances at a given time'), ('state.n.02', 'the way something is with respect to its main attributes'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('sine.n.01')
# ratio of the length of the side opposite the given angle to the length of the hypotenuse of a right-angled triangle
# [('trigonometric_function.n.01', 'function of an angle expressed as a ratio of the length of the sides of right-angled triangle containing the angle'), ('function.n.01', '(mathematics) a mathematical relation such that each element of a given set (the domain of the function) is associated with an element of another set (the range of the function)'), ('mathematical_relation.n.01', 'a relation between mathematical expressions (such as equality or inequality)'), ('relation.n.01', 'an abstraction belonging to or characteristic of two entities or parts together'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('multitude.n.03')
# the common people generally
# [('group.n.01', 'any number of entities (members) considered as a unit'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('profit.n.02')
# the advantageous quality of being beneficial
# [('advantage.n.01', 'the quality of having a superior or more favorable position'), ('asset.n.01', 'a useful or valuable quality'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]
#
# Synset('military_capability.n.01')
# capability in terms of personnel and materiel that affect the capacity to fight a war
# [('capability.n.01', 'the quality of being capable -- physically or intellectually or legally'), ('ability.n.01', 'the quality of being able to perform; a quality that permits or facilitates achievement or accomplishment'), ('quality.n.01', 'an essential and distinguishing attribute of something or someone'), ('attribute.n.02', 'an abstraction belonging to or characteristic of an entity'), ('abstraction.n.06', 'a general concept formed by extracting common features from specific examples'), ('entity.n.01', 'that which is perceived or known or inferred to have its own distinct existence (living or nonliving)')]

# %%
# Quality control: weed out superfluous rules

ruleMatches = defaultdict(set)

indent(reset = True)
info('beginning rule checks...')
for rule, ruleSet in catRules.items():
    if rule in ruleMatches:
        raise Exception('duplicate rule found: {} '.format(rule))
    for lex, synset in lexToSynset.items():
        hypernyms = set(h.name() for h in synset.closure(hyper))
        if len(hypernyms & ruleSet) == len(ruleSet):
            ruleMatches[rule].add(lex)
info('DONE!')
info('rules found: {}'.format(len(ruleMatches)))
info('terms found: {}'.format(len(set(synset for rule in ruleMatches for synset in ruleMatches[rule]))))
print()
info('comparing matches...')

ruleOverlaps = {}

for rule, matches in ruleMatches.items():
    overlaps = list()
    for compareRule, compareMatches in ruleMatches.items():
        if rule != compareRule and matches & compareMatches:
            if rule[0] != compareRule[0]:
                overlaps.append({
                                   'overlapper':compareRule,
                                   '#overlaps':len(matches&compareMatches),
                                    #'overlaps':list(F.gloss.v(n) for n in matches&compareMatches)
                                   '#my matches':len(matches),
                                   '#their matches':len(compareMatches),
                                   'my ruleSet': catRules[rule],
                                   'their ruleSet': catRules[compareRule]
                               })
            
    if overlaps:
        ruleOverlaps[rule] = overlaps
            
info('comparisons COMPLETE!')
# Out:
#   0.00s beginning rule checks...
#   2.10s DONE!
#   2.10s rules found: 43
#   2.10s terms found: 1130
#
#   2.11s comparing matches...
#   2.11s comparisons COMPLETE!

# %%
print(len(ruleOverlaps))
pprint(ruleOverlaps)
# Out:
# 5
# {('agency', 'living'): [{'#my matches': 178,
#                          '#overlaps': 25,
#                          '#their matches': 25,
#                          'my ruleSet': {'living_thing.n.01'},
#                          'overlapper': ('object', 'physical', 'plant'),
#                          'their ruleSet': {'plant.n.02'}}],
#  ('object', 'abstract', 'measure'): [{'#my matches': 55,
#                                       '#overlaps': 20,
#                                       '#their matches': 20,
#                                       'my ruleSet': {'measure.n.02'},
#                                       'overlapper': ('time', 'period'),
#                                       'their ruleSet': {'time_period.n.01'}},
#                                      {'#my matches': 55,
#                                       '#overlaps': 4,
#                                       '#their matches': 4,
#                                       'my ruleSet': {'measure.n.02'},
#                                       'overlapper': ('time', 'unit'),
#                                       'their ruleSet': {'time_unit.n.01'}}],
#  ('object', 'physical', 'plant'): [{'#my matches': 25,
#                                     '#overlaps': 25,
#                                     '#their matches': 178,
#                                     'my ruleSet': {'plant.n.02'},
#                                     'overlapper': ('agency', 'living'),
#                                     'their ruleSet': {'living_thing.n.01'}}],
#  ('time', 'period'): [{'#my matches': 20,
#                        '#overlaps': 20,
#                        '#their matches': 55,
#                        'my ruleSet': {'time_period.n.01'},
#                        'overlapper': ('object', 'abstract', 'measure'),
#                        'their ruleSet': {'measure.n.02'}}],
#  ('time', 'unit'): [{'#my matches': 4,
#                      '#overlaps': 4,
#                      '#their matches': 55,
#                      'my ruleSet': {'time_unit.n.01'},
#                      'overlapper': ('object', 'abstract', 'measure'),
#                      'their ruleSet': {'measure.n.02'}}]}

# %% [markdown]
# # 6. export the new list
#
# For conflicts, the node will be grouped with the smaller (the more specific, in theory) group.
#
# *[future improvement: track the max depth of each path for a given sense and take the deeper path]*
#
# Now we process the remaining lemmas and group them into their smaller categories. The file is exported.

# %%
lexToCat = defaultdict(dict)

for lexNode in accountedFor:
    for rule, matches in ruleMatches.items():
        if lexNode in matches:
            weight = len(matches) 
            if weight < lexToCat[lexNode].setdefault('weight', weight+1):
                lexToCat[lexNode]={'weight':weight,'cat':rule}
                
len(lexToCat)
# Out:
# 1130

# %%
fieldnames = ['pos','type','of kind']

exportList = dict( (F.lex.v(lex), {'cat': lexToCat[lex]['cat'][0], 
                                   'subcategory': lexToCat[lex]['cat'][1],
                                   'subsubcategory':lexToCat[lex]['cat'][2] if len(lexToCat[lex]['cat']) > 2 else ''
                                  }
                   ) for lex in lexToCat)

# %% [markdown]
# ## Special Adjustments:

# %%
del exportList['KNP/']
del exportList['ML>KT/']

# %%
with open('wordnetCategories.json','w') as file:
    json.dump(exportList, file)
