# %% [markdown]
# # Exploring Trees from the ETCBC Lingo Module
#
# Explore trees from the lingo module and examine the level of subphrase embedding that is reflected in the trees.

# %%
import sys, os, collections, re
from tf.fabric import Fabric

# import custom modules
bhsa_visual = '~/github/bhsa/programs' # for shebanq-like visualizations
tree_utils = '~/github/etcbc/lingo'    # tree methods for examining trees
sys.path.append(os.path.expanduser(bhsa_visual))
sys.path.append(os.path.expanduser(tree_utils))

from bhsa import Bhsa 
from trees.utils import structure, layout

# %%
TF = Fabric(locations='~/github/etcbc', modules=['bhsa/tf/2017', 'lingo/trees/tf/2017'])
api = TF.load('''
                book chapter verse
                sp pdp function tree
                lex g_cons_utf8
              ''')
api.makeAvailableIn(globals())

# instantiate visualizer
B = Bhsa(api, TF, version='2017')
# Out:
# This is Text-Fabric 3.2.5
# Api reference : https://github.com/Dans-labs/text-fabric/wiki/Api
# Tutorial      : https://github.com/Dans-labs/text-fabric/blob/master/docs/tutorial.ipynb
# Example data  : https://github.com/Dans-labs/text-fabric-data
#
# 116 features found and 0 ignored
#   0.00s loading features ...
#    |     0.01s B book                 from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.01s B chapter              from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.01s B verse                from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.18s B g_cons_utf8          from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.14s B sp                   from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.12s B pdp                  from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.06s B function             from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.05s B tree                 from /Users/cody/github/etcbc/lingo/trees/tf/2017
#    |     0.13s B lex                  from /Users/cody/github/etcbc/bhsa/tf/2017
#    |     0.00s Feature overview: 110 for nodes; 5 for edges; 1 configs; 7 computed
#   5.26s All features loaded/computed - for details use loadLog()

# %% [markdown]
# # Tree Set-Up
#
# Loading tree data for the first time...

# %%
gen_1 = T.nodeFromSection(('Genesis', 1, 1))
gen_1_sent = L.d(gen_1, 'sentence')[0]
gen_1_words = L.d(gen_1_sent, 'word')

F.tree.v(gen_1_sent)
# Out:
# '(S(C(PP(pp 0)(n 1))(VP(vb 2))(NP(n 3))(PP(U(pp 4)(dt 5)(n 6))(cj 7)(U(pp 8)(dt 9)(n 10)))))'

# %%
structure(F.tree.v(gen_1_sent))
# Out:
# ['S',
#  ['C',
#   ['PP', [('pp', 0)], [('n', 1)]],
#   ['VP', [('vb', 2)]],
#   ['NP', [('n', 3)]],
#   ['PP',
#    ['U', [('pp', 4)], [('dt', 5)], [('n', 6)]],
#    [('cj', 7)],
#    ['U', [('pp', 8)], [('dt', 9)], [('n', 10)]]]]]

# %% [markdown]
# Getting Hebrew into the number slots...

# %%
# code via Dirk Roorda
# https://github.com/ETCBC/lingo/blob/master/trees/example.ipynb

numPattern = re.compile('[0-9]+')

def fillWords(tree, start, wordRep):
    def numReplace(match):
        return wordRep(int(match.group(0)) + start)
    return numPattern.sub(numReplace, tree)

# %%
fillWords(F.tree.v(gen_1_sent), gen_1_words[0], F.lex.v)
# Out:
# '(S(C(PP(pp B)(n R>CJT/))(VP(vb BR>[))(NP(n >LHJM/))(PP(U(pp >T)(dt H)(n CMJM/))(cj W)(U(pp >T)(dt H)(n >RY/)))))'

# %%
completed_sent = fillWords(F.tree.v(gen_1_sent), gen_1_words[0], F.lex.v)

# %%
test = L.u(829049, 'sentence')[0]
test_tree = F.tree.v(test)
first_w = L.d(test, 'word')[0]

B.show([(test,)])
# Out:
# ## Result 0
# (**sentence** `1216242`)
# <div class="verse  ">
#
#     <div class="vl">
#         <div class="vs"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="show this passage in SHEBANQ">Micah 5:4</a></div><div class="nd">1428832</div>
#     </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">sentence</a> <span class="nd">1216240</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">clause</a> <span class="nd">487866</span>  <span class="rela">NA</span> <span class="typ">WQtX</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829034</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">וְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">conj</a></div>
# <div class="gl">and</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829035</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">הָיָ֥ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">verb</a></div>
# <div class="gl">be</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829036</span>  <span class="function">Subj</span> <span class="typ">DPrP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">זֶ֖ה </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">prde</a></div>
# <div class="gl">this</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829037</span>  <span class="function">PreC</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">שָׁלֹ֑ום </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">subs</a></div>
# <div class="gl">peace</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="satom  ">
#
#     <div class="sentence"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">sentence</a> <span class="nd">1216241</span>
#     </div>
#     <div class="atoms">
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">clause</a> <span class="nd">487867</span>  <span class="rela">NA</span> <span class="typ">CPen</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829038</span>  <span class="function">Frnt</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">אַשּׁ֣וּר׀ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">nmpr</a></div>
# <div class="gl">Asshur</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">clause</a> <span class="nd">487868</span>  <span class="rela">Resu</span> <span class="typ">xYq0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829039</span>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">כִּֽי־</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">conj</a></div>
# <div class="gl">that</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829040</span>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">יָבֹ֣וא </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">verb</a></div>
# <div class="gl">come</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  ">
#
#     <div class="phrase"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">phrase</a> <span class="nd">829041</span>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  ">
# <div class="h">בְ</div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">prep</a></div>
# <div class="gl">in</div>
#
# </div>
#
# <div class="word  ">
# <div class="h">אַרְצֵ֗נוּ </div>
# <div class="sp"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Micha&chapter=5&verse=4&version=2017&mr=m&qw=q&tp=txt_p&tr=hb&wget=v&qget=v&nget=vt" title="Micah 5:4">subs</a></div>
# <div class="gl">earth</div>
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  ">
#
#     <div class="clause"><a target="_blank" href="https://shebanq.ancient-data.org/hebr

# %%
print(layout(structure(test_tree), first_w, F.g_cons_utf8.v))
# Out:
#   S
#     C
#       CP
#         cj ו
#       VP
#         vb הקמנו
#       PP
#         pp עליו
#       NP
#         U
#           U
#             n שׁבעה
#           U
#             vb רעים
#         cj ו
#         U
#           U
#             n שׁמנה
#           U
#             U
#               n נסיכי
#             U
#               n אדם
