# %% [markdown]
# # Get Data

# %%
from collections import *
from tf.fabric import Fabric
from IPython.display import display, HTML

TF = Fabric(modules='Hebrew/etcbc4c')
api = TF.load('''
              book chapter verse 
              function pdp vt
              lex lex_utf8 g_word_utf8
              mother tab
              ''')
api.makeAvailableIn(globals())
# Out:
# This is Text-Fabric 2.3.0
# Api reference : https://github.com/ETCBC/text-fabric/wiki/Api
# Tutorial      : https://github.com/ETCBC/text-fabric/blob/master/docs/tutorial.ipynb
# Data sources  : https://github.com/ETCBC/text-fabric-data
# Data docs     : https://etcbc.github.io/text-fabric-data
# Shebanq docs  : https://shebanq.ancient-data.org/text
# Slack team    : https://shebanq.slack.com/signup
# Questions? Ask shebanq@ancient-data.org for an invite to Slack
# 109 features found and 0 ignored
#   0.00s loading features ...
#    |     0.01s B book                 from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.01s B chapter              from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.01s B verse                from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.18s B g_word_utf8          from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.17s B lex_utf8             from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.08s B function             from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.14s B pdp                  from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.13s B vt                   from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.14s B lex                  from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.18s B mother               from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.02s B tab                  from /Users/Cody/github/text-fabric-data/Hebrew/etcbc4c
#    |     0.00s Feature overview: 103 nodes; 5 edges; 1 configs; 7 computeds
#   5.23s All features loaded/computed - for details use loadLog()

# %%
def getLabel(clauseNode):
    '''
    convert a Text-Fabric node number into a label
    return a label of form: book.chapter.verse.clause
    '''
    bookNode = L.u(clauseNode, otype='book')[0]
    chapterNode = L.u(clauseNode, otype='chapter')[0]
    verseNode = L.u(clauseNode, otype='verse')[0]
    verseClauses = list(L.d(verseNode, otype='clause_atom'))
    clauseNum = verseClauses.index(clauseNode) + 1
    clauseLabel = '{}.{}.{}.{}'.format(F.book.v(bookNode), 
                                       F.chapter.v(chapterNode), 
                                       F.verse.v(verseNode), 
                                       clauseNum)
    return clauseLabel
    
def getEtcbcData(corpus):
    '''
    Gather the needed data from the Text-Fabric module;
    label clauses with a simple reference tag (ex. Psalms.1.1.1)
    return an embedded dictionary keyed by data labels...;
    '''
    # the corpus argument is a string; 
    # find the node number with a feature value that matches the corpus string
    # there will be only 1 result, so we use 'next' to pull the first result from the generator 
    corpus = next(book for book in F.otype.s('book') if F.book.v(book) == corpus)
    
    # now we pull all the clause node numbers from the corpus:
    clauseNodes = L.d(corpus, otype='clause_atom')

    # create a mapping for each mother clause to its daughter clauses
    # in Text-Fabric that information is stored the other way around
    # so we build up that data with a defaultdict with a list value:
    motherToDaughters = defaultdict(list)
    for clause in clauseNodes:
        if F.tab.v(clause) == 0: # do not store parallel daughter clauses
            continue
        daughter = getLabel(clause)
        for mother in E.mother.f(clause):
            motherToDaughters[mother].append(daughter)
    
    # we will store all of the clause data in this dict:
    clauses = OrderedDict()
    
    # iterate over the clause node numbers and gather the data to be returned
    # the data is stored in the clauses ordered dictionary
    for clause in clauseNodes:
        clauseLabel = getLabel(clause)
        wordNodes = L.d(clause, otype='word')
        text = T.text(wordNodes)
        indentation = F.tab.v(clause)
        phraseNodes = L.d(clause, otype='phrase')
        timePhrases = tuple(phrase for phrase in phraseNodes if F.function.v(phrase) == 'Time')
        timePhraseText = tuple(T.text(L.d(phrase, otype='word')) for phrase in timePhrases)
        daughters = motherToDaughters.get(clause, [])
        mother = getLabel(E.mother.f(clause)[0]) if E.mother.f(clause) else None
        clauses[clauseLabel] = {
                                'text': text,
                                'timePhraseText': timePhraseText,
                                'daughters': daughters,
                                'mother': mother,
                                'timeCategories':[],
                                'indentation':indentation,
                                'etcbcClauseNode': clause #!! REMOVE LATER
                                }
    return clauses

# %%
def climbClauseTree(clause, clauseDict, span, coverage):
    '''
    recursively climb the clause tree and build the time spans
    if a time marker occurs inside the tree, break the span 
    span is a list that accrues as the code descends the tree
    coverage is a set that tracks which clauses are accounted for
    '''    
    for daughter in clauseDict[clause]['daughters']:
        timeMarkers = clauseDict[daughter]['timePhraseText']
        if timeMarkers:
            continue
        else:
            span.append(daughter)
            coverage.add(daughter)
            climbClauseTree(daughter, clauseDict, span, coverage)

def buildTimeSpans(clauseDict):
    '''
    loop through all clauses and call the climbClauseTree function
    each timespan is stored in timeSpans dict, keyed by its first clause
    coverage tracks which clauses are accounted for to avoid overlap
    '''
    timeSpans = OrderedDict()
    coverage = set()
    for clause, cData in clauseDict.items():
        if clause not in coverage and cData['timePhraseText']:
            span = []
            span.append(clause)
            climbClauseTree(clause, clauseDict, span, coverage)
            timeSpans[clause] = span
    return timeSpans

# %%
def buildDisplay(clauseDict, spanDict):
    '''
    compile HTML code to display:
        1. plain text clauses
        2. indent clauses based on relationship to each other
        3. shade each clause within each time-span
    '''
    
    templates = {
                 'div' : '<div style="text-align: right; padding-right: 450px">{data}</div>',
                 'label' : '<span>{clauseLabel}</span>',
                 'clause' : '<span{style}>{clause}</span>{label}<br>\n',
                 'colorStyle' : ' style="background-color:{color}"',
                 'tab' : '&nbsp&nbsp&nbsp&nbsp',
                 'colors' : ('#fffdaf','#f9c9a7')
                }
    
    inTimeSpan = set(cl for span in spanDict 
                     for cl in spanDict[span])
    
    # compile the code for the clause display in 'clauses' string
    clauses = ''
    currentColor = templates['colors'][1]
    
    for clause, clauseData in clauseDict.items():
        
        if clause in spanDict:
            color = next(col for col in templates['colors'] if col != currentColor)
            for sClause in spanDict[clause]:
                currentColor = color
                colorStyle = templates['colorStyle'].format(color=color)
                indentation = templates['tab'] * clauseDict[sClause]['indentation']
                clauseText = clauseDict[sClause]['text'] + indentation
                clauseDisplay = templates['clause'].format(style = colorStyle,
                                                           label = templates['tab'] + sClause,
                                                           clause = clauseText)
                clauses += clauseDisplay
                
        elif clause not in inTimeSpan:
            indentation = templates['tab'] * clauseData['indentation']
            clauseText = clauseData['text'] + indentation
            clauseDisplay = templates['clause'].format(style = '',
                                                       label = templates['tab'] + clause,
                                                       clause = clauseText)
            clauses += clauseDisplay
            
        else:
            continue
            
    htmlDiv = templates['div'].format(data=clauses)
    return htmlDiv

# %%
test = getEtcbcData('Genesis')

# %%
spans = buildTimeSpans(test)

# %%
body = buildDisplay(test, spans)

with open('test.html', 'w') as file:
    file.write('<HTML>')
    file.write('<meta charset="UTF-8">')
    file.write('<HEAD>')
    file.write('</HEAD>')
    file.write('<BODY>')
    file.write(body)
    file.write('</BODY>')
    file.write('</HTML>')

# %% [markdown]
# # Test Field

# %%
# PRINT SPANS:
pprint(list(spans.items())[:100])
# Out:
# [('Genesis.1.1.1',
#   ['Genesis.1.1.1',
#    'Genesis.1.2.1',
#    'Genesis.1.2.2',
#    'Genesis.1.2.3',
#    'Genesis.1.3.1',
#    'Genesis.1.3.2',
#    'Genesis.1.3.3',
#    'Genesis.1.4.1',
#    'Genesis.1.4.2',
#    'Genesis.1.4.3',
#    'Genesis.1.5.1',
#    'Genesis.1.5.2',
#    'Genesis.1.5.3',
#    'Genesis.1.5.4',
#    'Genesis.1.5.5',
#    'Genesis.1.6.1',
#    'Genesis.1.6.2',
#    'Genesis.1.6.3',
#    'Genesis.1.7.1',
#    'Genesis.1.7.2',
#    'Genesis.1.7.3',
#    'Genesis.1.7.4',
#    'Genesis.1.7.5',
#    'Genesis.1.7.6',
#    'Genesis.1.8.1',
#    'Genesis.1.8.2',
#    'Genesis.1.8.3',
#    'Genesis.1.8.4',
#    'Genesis.1.9.1',
#    'Genesis.1.9.2',
#    'Genesis.1.9.3',
#    'Genesis.1.9.4',
#    'Genesis.1.10.1',
#    'Genesis.1.10.2',
#    'Genesis.1.10.3',
#    'Genesis.1.10.4',
#    'Genesis.1.11.1',
#    'Genesis.1.11.2',
#    'Genesis.1.11.3',
#    'Genesis.1.11.4',
#    'Genesis.1.11.5',
#    'Genesis.1.11.6',
#    'Genesis.1.11.7',
#    'Genesis.1.11.8',
#    'Genesis.1.12.1',
#    'Genesis.1.12.2',
#    'Genesis.1.12.3',
#    'Genesis.1.12.4',
#    'Genesis.1.12.5',
#    'Genesis.1.12.6',
#    'Genesis.1.12.7',
#    'Genesis.1.12.8',
#    'Genesis.1.13.1',
#    'Genesis.1.13.2',
#    'Genesis.1.13.3',
#    'Genesis.1.14.1',
#    'Genesis.1.14.2',
#    'Genesis.1.14.3',
#    'Genesis.1.14.4',
#    'Genesis.1.15.1',
#    'Genesis.1.15.2',
#    'Genesis.1.15.3',
#    'Genesis.1.16.1',
#    'Genesis.1.16.2',
#    'Genesis.1.16.3',
#    'Genesis.1.16.4',
#    'Genesis.1.17.1',
#    'Genesis.1.17.2',
#    'Genesis.1.18.1',
#    'Genesis.1.18.2',
#    'Genesis.1.18.3',
#    'Genesis.1.18.4',
#    'Genesis.1.19.1',
#    'Genesis.1.19.2',
#    'Genesis.1.19.3',
#    'Genesis.1.20.1',
#    'Genesis.1.20.2',
#    'Genesis.1.20.3',
#    'Genesis.1.21.1',
#    'Genesis.1.21.2',
#    'Genesis.1.21.3',
#    'Genesis.1.21.4',
#    'Genesis.1.21.5',
#    'Genesis.1.21.6',
#    'Genesis.1.21.7',
#    'Genesis.1.21.8',
#    'Genesis.1.22.1',
#    'Genesis.1.22.2',
#    'Genesis.1.22.3',
#    'Genesis.1.22.4',
#    'Genesis.1.22.5',
#    'Genesis.1.22.6',
#    'Genesis.1.23.1',
#    'Genesis.1.23.2',
#    'Genesis.1.23.3',
#    'Genesis.1.24.1',
#    'Genesis.1.24.2',
#    'Genesis.1.24.3',
#    'Genesis.1.24.4',
#    'Genesis.1.25.1',
#    'Genesis.1.25.2',
#    'Genesis.1.25.3',
#    'Genesis.1.25.4',
#    'Genesis.1.25.5',
#    'Genesis.1.26.1',
#    'Genesis.1.26.2',
#    'Genesis.1.26.3',
#    'Genesis.1.26.4',
#    'Genesis.1.27.1',
#    'Genesis.1.27.2',
#    'Genesis.1.27.3',
#    'Genesis.1.28.1',
#    'Genesis.1.28.2',
#    'Genesis.1.28.3',
#    'Genesis.1.28.4',
#    'Genesis.1.28.5',
#    'Genesis.1.28.6',
#    'Genesis.1.28.7',
#    'Genesis.1.28.8',
#    'Genesis.1.29.1',
#    'Genesis.1.29.2',
#    'Genesis.1.29.3',
#    'Genesis.1.29.4',
#    'Genesis.1.29.5',
#    'Genesis.1.29.6',
#    'Genesis.1.29.7',
#    'Genesis.1.29.8',
#    'Genesis.1.30.1',
#    'Genesis.1.30.2',
#    'Genesis.1.30.3',
#    'Genesis.1.30.4',
#    'Genesis.1.31.1',
#    'Genesis.1.31.2',
#    'Genesis.1.31.3',
#    'Genesis.1.31.4',
#    'Genesis.1.31.5',
#    'Genesis.1.31.6']),
#  ('Genesis.2.2.1', ['Genesis.2.2.1', 'Genesis.2.2.2']),
#  ('Genesis.2.2.3', ['Genesis.2.2.3', 'Genesis.2.2.4']),
#  ('Genesis.2.5.1', ['Genesis.2.5.1']),
#  ('Genesis.2.5.2',
#   ['Genesis.2.5.2',
#    'Genesis.2.5.3',
#    'Genesis.2.5.4',
#    'Genesis.2.5.5',
#    'Genesis.2.6.1',
#    'Genesis.2.6.2']),
#  ('Genesis.2.17.3', ['Genesis.2.17.3', 'Genesis.2.17.4', 'Genesis.2.17.5']),
#  ('Genesis.3.8.2', ['Genesis.3.8.2']),
#  ('Genesis.3.14.5',
#   ['Genesis.3.14.5', 'Genesis.3.15.1', 'Genesis.3.15.2', 'Genesis.3.15.3']),
#  ('Genesis.3.17.8',
#   ['Genesis.3.17.8',
#    'Genesis.3.18.1',
#    'Genesis.3.18.2',
#    'Genesis.3.19.1',
#    'Genesis.3.19.2',
#    'Genesis.3.19.3',
#    'Genesis.3.19.4',
#    'Genesis.3.19.5']),
#  ('Genesis.3.22.8', ['Genesis.3.22.8']),
#  ('Genesis.4.3.1',
#   ['Genesis.4.3.1',
#    'Genesis.4.3.2',
#    'Genesis.4.4.1',
#    'Genesis.4.4.2',
#    'Genesis.4.5.1',
#    'Genesis.4.5.2',
#    'Genesis.4.5.3',
#    'Genesis.4.6.1',
#    'Genesis.4.6.2',
#    'Genesis.4.6.3',
#    'Genesis.4.7.1',
#    'Genesis.4.7.3',
#    'Genesis.4.7.2',
#    'Genesis.4.7.4',
#    'Genesis.4.7.5',
#    'Genesis.4.7.6',
#    'Genesis.4.7.7',
#    'Genesis.4.8.1',
#    'Genesis.4.8.2',
#    'Genesis.4.8.3',
#    'Genesis.4.8.4',
#    'Genesis.4.8.5',
#    'Genesis.4.9.1',
#    'Genesis.4.9.2',
#    'Genesis.4.9.3',
#    'Genesis.4.9.4',
#    'Genesis.4.9.5',
#    'Genesis.4.10.1',
#    'Genesis.4.10.2',
#    'Genesis.4.10.3',
#    'Genesis.4.11.1',
#    'Genesis.4.11.2',
#    'Genesis.4.11.3',
#    'Genesis.4.11.4',
#    'Genesis.4.12.1',
#    'Genesis.4.12.2',
#    'Genesis.4.12.3',
#    'Genesis.4.12.4',
#    'Genesis.4.13.1',
#    'Genesis.4.13.2',
#    'Genesis.4.13.3',
#    'Genesis.4.15.1',
#    'Genesis.4.15.2',
#    'Genesis.4.15.3',
#    'Genesis.4.15.4',
#    'Genesis.4.15.5',
#    'Genesis.4.16.1',
#    'Genesis.4.16.2']),
#  ('Genesis.4.14.1',
#   ['Genesis.4.14.1',
#    'Genesis.4.14.2',
#    'Genesis.4.14.3',
#    'Genesis.4.14.4',
#    'Genesis.4.14.5',
#    'Genesis.4.14.6',
#    'Genesis.4.14.7']),
#  ('Genesis.4.26.3', ['Genesis.4.26.3', 'Genesis.4.26.4']),
#  ('Genesis.5.1.2',
#   ['Genesis.5.1.2',
#    'Genesis.5.1.3',
#    'Genesis.5.1.4',
#    'Genesis.5.2.1',
#    'Genesis.5.2.2']),
#  ('Genesis.5.2.3', ['Genesis.5.2.3', 'Genesis.5.2.4']),
#  ('Genesis.5.3.1',
#   ['Genesis.5.3.1',
#    'Genesis.5.3.2',
#    'Genesis.5.3.3',
#    'Genesis.5.4.1',
#    'Genesis.5.4.2',
#    'Genesis.5.4.3',
#    'Genesis.5.4.4',
#    'Genesis.5.5.1',
#    'Genesis.5.5.2',
#    'Genesis.5.5.3',
#    'Genesis.5.5.4']),
#  ('Genesis.5.6.1',
#   ['Genesis.5.6.1',
#    'Genesis.5.6.2',
#    'Genesis.5.7.1',
#    'Genesis.5.7.2',
#    'Genesis.5.7.4',
#    'Genesis.5.8.1',
#    'Genesis.5.8.2']),
#  ('Genesis.5.7.3', ['Genesis.5.7.3']),
#  ('Genesis.5.9.1',
#   ['Genesis.5.9.1',
#    'Genesis.5.9.2',
#    'Genesis.5.10.1',
#    'Genesis.5.10.2',
#    'Genesis.5.10.4',
#    'Genesis.5.11.1',
#    'Genesis.5.11.2']),
#  ('Genesis.5.10.3', ['Genesis.5.10.3']),
#  ('Genesis.5.12.1',
#   ['Genesis.5.12.1',
#    'Genesis.5.12.2',
#    'Genesis.5.13.1',
#    'Genesis.5.13.2',
#    'Genesis.5.13.4',
#    'Genesis.5.14.1',
#    'Genesis.5.14.2']),
#  ('Genesis.5.13.3', ['Genesis.5.13.3']),
#  ('Genesis.5.15.1',
#   ['Genesis.5.15.1',
#    'Genesis.5.15.2',
#    'Genesis.5.16.1',
#    'Genesis.5.16.2',
#    'Genesis.5.16.4',
#    'Genesis.5.17.1',
#    'Genesis.5.17.2']),
#  ('Genesis.5.16.3', ['Genesis.5.16.3']),
#  ('Genesis.5.18.1',
#   ['Genesis.5.18.1',
#    'Genesis.5.18.2',
#    'Genesis.5.19.1',
#    'Genesis.5.19.2',
#    'Genesis.5.19.4',
#    'Genesis.5.20.1',
#    'Genesis.5.20.2']),
#  ('Genesis.5.19.3', ['Genesis.5.19.3']),
#  ('Genesis.5.21.1',
#   ['Genesis.5.21.1',
#    'Genesis.5.21.2',
#    'Genesis.5.22.1',
#    'Genesis.5.22.2',
#    'Genesis.5.22.4',
#    'Genesis.5.23.1',
#    'Genesis.5.24.1',
#    'Genesis.5.24.2',
#    'Genesis.5.24.3']),
#  ('Genesis.5.22.3', ['Genesis.5.22.3']),
#  ('Genesis.5.25.1',
#   ['Genesis.5.25.1',
#    'Genesis.5.25.2',
#    'Genesis.5.26.1',
#    'Genesis.5.26.2',
#    'Genesis.5.26.4',
#    'Genesis.5.27.1',
#    'Genesis.5.27.2']),
#  ('Genesis.5.26.3', ['Genesis.5.26.3']),
#  ('Genesis.5.28.1',
#   ['Genesis.5.28.1',
#    'Genesis.5.28.2',
#    'Genesis.5.29.1',
#    'Genesis.5.29.2',
#    'Genesis.5.29.3',
#    'Genesis.5.29.4',
#    'Genesis.5.30.1',
#    'Genesis.5.30.2',
#    'Genesis.5.30.4',
#    'Genesis.5.31.1',
#    'Genesis.5.31.2',
#    'Genesis.5.32.1',
#    'Genesis.5.32.2']),
#  ('Genesis.5.30.3', ['Genesis.5.30.3']),
#  ('Genesis.6.3.2', ['Genesis.6.3.2', 'Genesis.6.3.3', 'Genesis.6.3.4']),
#  ('Genesis.6.4.1',
#   ['Genesis.6.4.1',
#    'Genesis.6.4.3',
#    'Genesis.6.4.4',
#    'Genesis.6.4.5',
#    'Genesis.6.4.6',
#    'Genesis.6.4.7']),
#  ('Genesis.6.4.2', ['Genesis.6.4.2']),
#  ('Genesis.6.5.3', ['Genesis.6.5.3']),
#  ('Genesis.7.4.1',
#   ['Genesis.7.4.1', 'Genesis.7.4.2', 'Genesis.7.4.3', 'Genesis.7.4.4']),
#  ('Genesis.7.10.1', ['Genesis.7.10.1', 'Genesis.7.10.2']),
#  ('Genesis.7.11.1', ['Genesis.7.11.1', 'Genesis.7.11.2']),
#  ('Genesis.7.12.1', ['Genesis.7.12.1']),
#  ('Genesis.7.13.1',
#   ['Genesis.7.13.1',
#    'Genesis.7.14.1',
#    'Genesis.7.14.2',
#    'Genesis.7.14.3',
#    'Genesis.7.15.1',
#    'Genesis.7.15.2',
#    'Genesis.7.16.1',
#    'Genesis.7.16.3',
#    'Genesis.7.16.2',
#    'Genesis.7.16.4',
#    'Genesis.7.16.5']),
#  ('Genesis.7.17.1',
#   ['Genesis.7.17.1',
#    'Genesis.7.17.2',
#    'Genesis.7.17.3',
#    'Genesis.7.17.4',
#    'Genesis.7.18.1',
#    'Genesis.7.18.2',
#    'Genesis.7.18.3',
#    'Genesis.7.19.1',
#    'Genesis.7.19.2',
#    'Genesis.7.19.3',
#    'Genesis.7.20.1',
#    'Genesis.7.20.2',
#    'Genesis.7.21.1',
#    'Genesis.7.21.2',
#    'Genesis.7.21.3',
#    'Genesis.7.21.4',
#    'Genesis.7.21.5',
#    'Genesis.7.22.1',
#    'Genesis.7.22.2',
#    'Genesis.7.22.3',
#    'Genesis.7.22.4',
#    'Genesis.7.22.5',
#    'Genesis.7.23.1',
#    'Genesis.7.23.2',
#    'Genesis.7.23.3',
#    'Genesis.7.23.4',
#    'Genesis.7.23.5',
#    'Genesis.7.23.6']),
#  ('Genesis.7.24.1', ['Genesis.7.24.1']),
#  ('Genesis.8.3.2', ['Genesis.8.3.2']),
#  ('Genesis.8.4.1', ['Genesis.8.4.1']),
#  ('Genesis.8.5.1', ['Genesis.8.5.1']),
#  ('Genesis.8.5.2', ['Genesis.8.5.2']),
#  ('Genesis.8.6.1',
#   ['Genesis.8.6.1',
#    'Genesis.8.6.2',
#    'Genesis.8.6.3',
#    'Genesis.8.7.1',
#    'Genesis.8.7.2',
#    'Genesis.8.7.3',
#    'Genesis.8.8.1',
#    'Genesis.8.8.2',
#    'Genesis.8.8.3',
#    'Genesis.8.9.1',
#    'Genesis.8.9.2',
#    'Genesis.8.9.3',
#    'Genesis.8.9.4',
#    'Genesis.8.9.5',
#    'Genesis.8.9.6']),
#  ('Genesis.8.10.1', ['Genesis.8.10.1', 'Genesis.8.10.2', 'Genesis.8.10.3']),
#  ('Genesis.8.11.1',
#   ['Genesis.8.11.1', 'Genesis.8.11.2', 'Genesis.8.11.3', 'Genesis.8.11.4']),
#  ('Genesis.8.12.1',
#   ['Genesis.8.12.1', 'Genesis.8.12.2', 'Genesis.8.12.3', 'Genesis.8.12.4']),
#  ('Genesis.8.13.2',
#   ['Genesis.8.13.2', 'Genesis.8.13.3', 'Genesis.8.13.4', 'Genesis.8.13.5']),
#  ('Genesis.8.14.1',
#   ['Genesis.8.14.1',
#    'Genesis.8.15.1',
#    'Genesis.8.15.2',
#    'Genesis.8.16.1',
#    'Genesis.8.17.1',
#    'Genesis.8.17.2',
#    'Genesis.8.17.3',
#    'Genesis.8.17.4',
#    'Genesis.8.17.5',
#    'Genesis.8.17.6',
#    'Genesis.8.17.7',
#    'Genesis.8.17.8',
#    'Genesis.8.18.1',
#    'Genesis.8.19.1',
#    'Genesis.8.19.2',
#    'Genesis.8.19.3',
#    'Genesis.8.20.1',
#    'Genesis.8.20.2',
#    'Genesis.8.20.3',
#    'Genesis.8.21.1',
#    'Genesis.8.21.2',
#    'Genesis.8.21.3',
#    'Genesis.8.21.4',
#    'Genesis.8.21.5',
#    'Genesis.8.21.6',
#    'Genesis.8.21.7',
#    'Genesis.8.21.8']),
#  ('Genesis.8.22.1', ['Genesis.8.22.1']),
#  ('Genesis.9.12.5', ['Genesis.9.12.5']),
#  ('Genesis.9.28.1', ['Genesis.9.28.1']),
#  ('Genesis.9.29.1', ['Genesis.9.29.1', 'Genesis.9.29.2']),
#  ('Genesis.10.1.2', ['Genesis.10.1.2']),
#  ('Genesis.10.18.2',
#   ['Genesis.10.18.2',
#    'Genesis.10.19.1',
#    'Genesis.10.19.2',
#    'Genesis.10.19.3',
#    'Genesis.10.19.4',
#    'Genesis.10.19.5']),
#  ('Genesis.10.25.3', ['Genesis.10.25.3']),
#  ('Genesis.10.32.2', ['Genesis.10.32.2']),
#  ('Genesis.11.10.3', ['Genesis.11.10.3']),
#  ('Genesis.11.11.3', ['Genesis.11.11.3']),
#  ('Genesis.11.12.1',
#   ['Genesis.11.12.1',
#    'Genesis.11.12.2',
#    'Genesis.11.13.1',
#    'Genesis.11.13.2',
#    'Genesis.11.13.4']),
#  ('Genesis.11.13.3', ['Genesis.11.13.3']),
#  ('Genesis.11.14.1',
#   ['Genesis.11.14.1',
#    'Genesis.11.14.2',
#    'Genesis.11.15.1',
#    'Genesis.11.15.2',
#    'Genesis.11.15.4']),
#  ('Genesis.11.15.3', ['Genesis.11.15.3']),
#  ('Genesis.11.16.1',
#   ['Genesis.11.16.1',
#    'Genesis.11.16.2',
#    'Genesis.11.17.1',
#    'Genesis.11.17.2',
#    'Genesis.11.17.4']),
#  ('Genesis.11.17.3', ['Genesis.11.17.3']),
#  ('Genesis.11.18.1',
#   ['Genesis.11.18.1',
#    'Genesis.11.18.2',
#    'Genesis.11.19.1',
#    'Genesis.11.19.2',
#    'Genesis.11.19.4']),
#  ('Genesis.11.19.3', ['Genesis.11.19.3']),
#  ('Genesis.11.20.1',
#   ['Genesis.11.20.1',
#    'Genesis.11.20.2',
#    'Genesis.11.21.1',
#    'Genesis.11.21.2',
#    'Genesis.11.21.4']),
#  ('Genesis.11.21.3', ['Genesis.11.21.3']),
#  ('Genesis.11.22.1',
#   ['Genesis.11.22.1',
#    'Genesis.11.22.2',
#    'Genesis.11.23.1',
#    'Genesis.11.23.2',
#    'Genesis.11.23.4']),
#  ('Genesis.11.23.3', ['Genesis.11.23.3']),
#  ('Genesis.11.24.1',
#   ['Genesis.11.24.1',
#    'Genesis.11.24.2',
#    'Genesis.11.25.1',
#    'Genesis.11.25.2',
#    'Genesis.11.25.4']),
#  ('Genesis.11.25.3', ['Genesis.11.25.3']),
#  ('Genesis.11.26.1', ['Genesis.11.26.1', 'Genesis.11.26.2']),
#  ('Genesis.12.6.2', ['Genesis.12.6.2']),
#  ('Genesis.13.3.2', ['Genesis.13.3.2']),
#  ('Genesis.13.4.2', ['Genesis.13.4.2']),
#  ('Genesis.13.7.2', ['Genesis.13.7.2']),
#  ('Genesis.13.15.4', ['Genesis.13.15.4']),
#  ('Genesis.14.1.1',
#   ['Genesis.14.1.1',
#    'Genesis.14.2.1',
#    'Genesis.14.2.2',
#    'Genesis.14.3.1',
#    'Genesis.14.3.2']),
#  ('Genesis.14.4.1', ['Genesis.14.4.1']),
#  ('Genesis.14.4.2', ['Genesis.14.4.2']),
#  ('Genesis.14.5.1',
#   ['Genesis.14.5.1',
#    'Genesis.14.5.2',
#    'Genesis.14.5.3',
#    'Genesis.14.5.4',
#    'Genesis.14.5.5',
#    'Genesis.14.6.1',
#    'Genesis.14.6.2',
#    'Genesis.14.7.1',
#    'Genesis.14.7.2',
#    'Genesis.14.7.3',
#    'Genesis.14.7.4',
#    'Genesis.14.7.5',
#    'Genesis.14.8.1',
#    'Genesis.14.8.2',
#    'Genesis.14.8.3',
#    'Genesis.14.9.1',
#    'Genesis.14.9.2',
#    'Genesis.14.10.1',
#    'Genesis.14.10.2',
#    'Genesis.14.10.3',
#    'Genesis.14.10.4',
#    'Genesis.14.11.1',
#    'Genesis.14.11.2',
#    'Genesis.14.12.1',
#    'Genesis.14.12.2',
#    'Genesis.14.12.3',
#    'Genesis.14.13.1',
#    'Genesis.14.13.2',
#    'Genesis.14.13.3',
#    'Genesis.14.13.4',
#    'Genesis.14.14.1',
#    'Genesis.14.14.2',
#    'Genesis.14.14.3',
#    'Genesis.14.14.4']),
#  ('Genesis.14.15.1',
#   ['Genesis.14.15.1',
#    'Genesis.14.15.2',
#    'Genesis.14.15.3',
#    'Genesis.14.15.4',
#    'Genesis.14.16.1',
#    'Genesis.14.16.2',
#    'Genesis.14.17.1',
#    'Genesis.14.17.2',
#    'Genesis.14.17.3',
#    'Genesis.14.17.4',
#    'Genesis.14.17.5',
#    'Genesis.14.17.6',
#    'Genesis.14.17.7',
#    'Genesis.14.18.1',
#    'Genesis.14.18.2',
#    'Genesis.14.19.1',
#    'Genesis.14.19.2',
#    'Genesis.14.19.3',
#    'Genesis.14.20.1',
#    'Genesis.14.20.2',
#    'Genesis.14.20.3',
#    'Genesis.14.21.1',
#    'Genesis.14.21.2',
#    'Genesis.14.21.3',
#    'Genesis.14.22.1',
#    'Genesis.14.22.2',
#    'Genesis.14.23.1',
#    'Genesis.14.23.2',
#    'Genesis.14.23.3',
#    'Genesis.14.23.4',
#    'Genesis.14.23.5',
#    'Genesis.14.24.1',
#    'Genesis.14.24.2',
#    'Genesis.14.24.3',
#    'Genesis.14.24.4',
#    'Genesis.14.24.5',
#    'Genesis.14.24.6',
#    'Genesis.14.24.7']),
#  ('Genesis.15.13.6', ['Genesis.15.13.6']),
#  ('Genesis.15.14.4', ['Genesis.15.14.4']),
#  ('Genesis.15.16.2', ['Genesis.15.16.2']),
#  ('Genesis.15.18.1',
#   ['Genesis.15.18.1',
#    'Genesis.15.18.2',
#    'Genesis.15.18.3',
#    'Genesis.15.19.1',
#    'Genesis.15.20.1',
#    'Genesis.15.21.1']),
#  ('Genesis.16.3.1',
#   ['Genesis.16.3.1',
#    'Genesis.16.3.2',
#    'Genesis.16.3.3',
#    'Genesis.16.4.1',
#    'Genesis.16.4.2',
#    'Genesis.16.4.3',
#    'Genesis.16.4.4',
#    'Genesis.16.4.5',
#    'Genesis.16.5.1',
#    'Genesis.16.5.2',
#    'Genesis.16.5.3',
#    'Genesis.16.5.4',
#    'Genesis.16.5.5',
#    'Genesis.16.5.6',
#    'Genesis.16.5.7',
#    'Genesis.16.6.1',
#    'Genesis.16.6.2',
#    'Genesis.16.6.3',
#    'Genesis.16.6.4',
#    'Genesis.16.6.5',
#    'Genesis.16.6.6',
#    'Genesis.16.7.1',
#    'Genesis.16.8.1',
#    'Genesis.16.8.2',
#    'Genesis.16.8.3',
#    'Genesis.16.8.4',
#    'Genesis.16.8.5',
#    'Genesis.16.8.6',
#    'Genesis.16.9.1',
#    'Genesis.16.9.2',
#    'Genesis.16.9.3',
#    'Genesis.16.10.1',
#    'Genesis.16.10.2',
#    'Genesis.16.10.3',
#    'Genesis.16.11.1',
#    'Genesis.16.11.2',
#    'Genesis.16.11.3',
#    'Genesis.16.11.4',
#    'Genesis.16.11.5',
#    'Genesis.16.12.1',
#    'Genesis.16.12.2',
#    'Genesis.16.12.3',
#    'Genesis.16.12.4',
#    'Genesis.16.13.1',
#    'Genesis.16.13.2',
#    'Genesis.16.13.3',
#    'Genesis.16.13.4',
#    'Genesis.16.13.5',
#    'Genesis.16.13.6',
#    'Genesis.16.14.1',
#    'Genesis.16.14.2',
#    'Genesis.16.15.1',
#    'Genesis.16.15.2',
#    'Genesis.16.15.3',
#    'Genesis.16.15.4',
#    'Genesis.16.16.1',
#    'Genesis.16.16.2']),
#  ('Genesis.17.21.2', ['Genesis.17.21.2']),
#  ('Genesis.17.23.2',
#   ['Genesis.17.23.2',
#    'Genesis.17.23.3',
#    'Genesis.17.24.1',
#    'Genesis.17.24.2',
#    'Genesis.17.25.1',
#    'Genesis.17.25.2']),
#  ('Genesis.17.26.1', ['Genesis.17.26.1', 'Genesis.17.27.1']),
#  ('Genesis.18.5.3', ['Genesis.18.5.3', 'Genesis.18.5.4']),
#  ('Genesis.18.10.2', ['Genesis.18.10.2', 'Genesis.18.10.3']),
#  ('Genesis.18.14.2', ['Genesis.18.14.2', 'Genesis.18.14.3']),
#  ('Genesis.19.1.1',
#   ['Genesis.19.1.1',
#    'Genesis.19.1.2',
#    'Genesis.19.1.3',
#    'Genesis.19.1.4',
#    'Genesis.19.1.5',
#    'Genesis.19.1.6',
#    'Genesis.19.1.7',
#    'Genesis.19.2.1',
#    'Genesis.19.2.2',
#    'Genesis.19.2.3',
#    'Genesis.19.2.4',
#    'Genesis.19.2.5',
#    'Genesis.19.2.6',
#    'Genesis.19.2.7',
#    'Genesis.19.2.8',
#    'Genesis.19.2.9',
#    'Genesis.19.2.10',
#    'Genesis.19.2.11',
#    'Genesis.19.3.1',
#    'Genesis.19.3.2',
#    'Genesis.19.3.3',
#    'Genesis.19.3.4',
#    'Genesis.19.3.5',
#    'Genesis.19.3.6',
#    'Genesis.19.4.1',
#    'Genesis.19.4.2',
#    'Genesis.19.5.1',
#    'Genesis.19.5.2',
#    'Genesis.19.5.3',
#    'Genesis.19.5.5',
#    'Genesis.19.5.6',
#    'Genesis.19.6.1',
#    'Genesis.19.6.2',
#    'Genesis.19.7.1',
#    'Genesis.19.7.2',
#    'Genesis.19.7.3',
#    'Genesis.19.7.4',
#    'Genesis.19.8.1',
#    'Genesis.19.8.2',
#    'Genesis.19.8.3',
#    'Genesis.19.8.4',
#    'Genesis.19.8.5',
#    'Genesis.19.8.6',
#    'Genesis.19.9.1',
#    'Genesis.19.9.2',
#    'Genesis.19.9.3',
#    'Genesis.19.9.4',
#    'Genesis.19.9.5',
#    'Genesis.19.9.6',
#    'Genesis.19.9.8',
#    'Genesis.19.9.9',
#    'Genesis.19.9.10',
#    'Genesis.19.10.1',
#    'Genesis.19.10.2',
#    'Genesis.19.10.3',
#    'Genesis.19.11.1',
#    'Genesis.19.11.2',
#    'Genesis.19.11.3',
#    'Genesis.19.11.4',
#    'Genesis.19.11.5',
#    'Genesis.19.12.1',
#    'Genesis.19.12.2',
#    'Genesis.19.12.3',
#    'Genesis.19.12.4',
#    'Genesis.19.12.5',
#    'Genesis.19.13.1',
#    'Genesis.19.13.2',
#    'Genesis.19.13.3',
#    'Genesis.19.13.4',
#    'Genesis.19.14.1',
#    'Genesis.19.14.2',
#    'Genesis.19.14.3',
#    'Genesis.19.14.4',
#    'Genesis.19.14.5',
#    'Genesis.19.14.6',
#    'Genesis.19.14.7',
#    'Genesis.19.15.1',
#    'Genesis.19.15.2',
#    'Genesis.19.15.3',
#    'Genesis.19.15.4',
#    'Genesis.19.15.5',
#    'Genesis.19.15.6',
#    'Genesis.19.15.7',
#    'Genesis.19.16.1',
#    'Genesis.19.16.2',
#    'Genesis.19.16.3',
#    'Genesis.19.16.4',
#    'Genesis.19.17.1',
#    'Genesis.19.17.2',
#    'Genesis.19.17.3',
#    'Genesis.19.17.4',
#    'Genesis.19.17.5',
#    'Genesis.19.17.6',
#    'Genesis.19.17.7',
#    'Genesis.19.17.8',
#    'Genesis.19.18.1',
#    'Genesis.19.18.2',
#    'Genesis.19.18.3',
#    'Genesis.19.19.1',
#    'Genesis.19.19.2',
#    'Genesis.19.19.3',
#    'Genesis.19.19.4',
#    'Genesis.19.19.5',
#    'Genesis.19.19.6',
#    'Genesis.19.19.7',
#    'Genesis.19.19.8',
#    'Genesis.19.20.1',
#    'Genesis.19.20.2',
#    'Genesis.19.20.3',
#    'Genesis.19.20.4',
#    'Genesis.19.20.5',
#    'Genesis.19.20.6',
#    'Genesis.19.21.1',
#    'Genesis.19.21.2',
#    'Genesis.19.21.3',
#    'Genesis.19.21.4',
#    'Genesis.19.22.1',
#    'Genesis.19.22.2',
#    'Genesis.19.22.3',
#    'Genesis.19.22.4',
#    'Genesis.19.22.5',
#    'Genesis.19.22.6',
#    'Genesis.19.23.1',
#    'Genesis.19.23.2',
#    'Genesis.19.24.1',
#    'Genesis.19.25.1',
#    'Genesis.19.26.1',
#    'Genesis.19.26.2'])]

# %%
test['Genesis.2.4.3']
# Out:
# {'daughters': ['Genesis.2.4.4', 'Genesis.2.5.1', 'Genesis.2.7.1'],
#  'etcbcClauseNode': 514731,
#  'indentation': 1,
#  'mother': 'Genesis.2.4.1',
#  'text': 'בְּיֹ֗ום ',
#  'timeCategories': [],
#  'timePhraseText': ()}

# %%
tClause = next(cl for cl in F.otype.s('clause_atom')
                   if F.book.v(L.u(cl, otype='book')[0]) == 'Genesis'
                   and F.chapter.v(L.u(cl, otype='chapter')[0]) == 2
                   and F.verse.v(L.u(cl, otype='verse')[0]) == 7
              )
tMom = E.mother.f(tClause)

words = L.d(tMom[0], otype='word')

T.text(words)
# Out:
# 'בְּיֹ֗ום '

# %%
corpus = next(book for book in F.otype.s('book') if F.book.v(book) == 'Genesis')

timePhrases = set( T.text(L.d(p, otype='word')) for p in L.d(corpus, otype='phrase') 
                   if F.function.v(p) == 'Time'
                 )

# %%
timePhrases
# Out:
# {'אֶ֖מֶשׁ ',
#  'אֶ֣מֶשׁ׀ ',
#  'אַ֣חֲרֵי כֵ֔ן ',
#  'אַֽחֲרֵי־כֵ֗ן ',
#  'אַֽחֲרֵי־כֵ֞ן ',
#  'אַחֲרֵ֖י מֹ֣ות אַבְרָהָ֑ם ',
#  'אַחֲרֵי֙ הַדְּבָרִ֣ים הָאֵ֔לֶּה ',
#  'אַחֲרֵי֙ מֹ֣ות אַבְרָהָ֔ם ',
#  'אַחֲרֵי־כֵ֑ן ',
#  'אַחֲרֵי־כֵ֥ן ',
#  'אַחֲרֵי־כֵן֙ ',
#  'אַחֲרֵי־כֵן֩ ',
#  'אַחֲרֵיהֶ֖ם ',
#  'אַחֲרֵיהֶ֗ן ',
#  'אַחֲרֵיהֶן֙ ',
#  'אַחַ֖ר ',
#  'אַחַ֗ר ',
#  'אַחַ֣ר ',
#  'אַחַ֣ר הַמַּבּ֑וּל ',
#  'אַחַ֥ר הַמַּבּֽוּל׃ ',
#  'אַחַ֥ר הַמַּבּֽוּל׃ פ ',
#  'אַחַר֙ ',
#  'אַחַר֙ הַדְּבָרִ֣ים הָאֵ֔לֶּה ',
#  'אַרְבַּ֥ע וּשְׁלֹשִׁ֖ים שָׁנָ֑ה ',
#  'אַרְבַּ֥ע מֵאֹ֖ות שָׁנָֽה׃ ',
#  'אַרְבַּֽע־עֶשְׂרֵ֤ה שָׁנָה֙ ',
#  'אַרְבָּעִ֣ים יֹ֔ום וְאַרְבָּעִ֖ים לָ֑יְלָה ',
#  'אַרְבָּעִ֣ים יֹ֔ום וְאַרְבָּעִ֖ים לָֽיְלָה׃ ',
#  'אַרְבָּעִ֣ים שָׁנָ֔ה וּשְׁמֹנֶ֥ה מֵאֹ֖ות שָׁנָ֑ה ',
#  'אַרְבָּעִ֥ים יֹ֖ום ',
#  'אָ֖ז ',
#  'אָ֣ז ',
#  'אָ֤ז ',
#  'אָ֥ז ',
#  'אָֽמֶשׁ׃ ',
#  'בְאַרְבַּע֩ עֶשְׂרֵ֨ה שָׁנָ֜ה ',
#  'בְיָמָיו֙ ',
#  'בַבֹּ֔קֶר ',
#  'בַבֹּ֨קֶר֙ ',
#  'בַחֹ֨דֶשׁ֙ הַשֵּׁנִ֔י ',
#  'בַיֹּ֛ום ',
#  'בַיֹּ֨ום הַשְּׁלִישִׁ֜י ',
#  'בָעֶ֔רֶב ',
#  'בְּאֶחָ֣ד לַחֹ֔דֶשׁ ',
#  'בְּאַחֲרִ֥ית הַיָּמִֽים׃ ',
